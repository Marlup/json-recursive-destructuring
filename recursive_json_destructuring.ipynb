# %%
import json
import random
import string
import pprint
from recursion_destructuring import( direct_recursive_destructure, 
                                     indirect_recursive_json_destructure
                                     )

# %%
def generate_random_data(levels):
    if levels == 0:
        return random.randint(1, 100)
    
    data = {}
    num_keys = random.randint(2, 5)
    for _ in range(num_keys):
        key = ''.join(random.choices(string.ascii_letters, k=5))
        value = generate_random_data(levels - 1)
        data[key] = value
    return data

nested_levels = random.randint(3, 5)
nested_data = generate_random_data(nested_levels)

with open('random_data.json', 'w') as json_file:
    json.dump(nested_data, json_file, indent=4)

print("Random data has been generated and saved to 'random_data.json'.")
# Out:
# Random data has been generated and saved to 'random_data.json'.

# %%
pprint.pprint(nested_data)
# Out:
# {'KxfoV': {'bfTwz': {'AMwdE': {'MLTPd': {'CEpVu': 43,
#                                          'NBSum': 51,
#                                          'PcAkH': 19,
#                                          'YHMxy': 74},
#                                'OJmXC': {'LOQIf': 31,
#                                          'RByWv': 57,
#                                          'TikHO': 41,
#                                          'vpeyk': 82},
#                                'QvbvW': {'blkjU': 15, 'vlaWQ': 34},
#                                'fUiiA': {'MNxzB': 88,
#                                          'MuFwc': 31,
#                                          'dAhhe': 19,
#                                          'fkevf': 1,
#                                          'wHEtd': 68},
#                                'pohSP': {'MkHxP': 65, 'mLSCy': 46}},
#                      'JRrvG': {'STksV': {'IEuRN': 32, 'NUnjm': 21, 'zTKCy': 33},
#                                'WUCBy': {'ORHSD': 12,
#                                          'UczcU': 67,
#                                          'VGeFg': 28,
#                                          'fPARd': 19},
#                                'aaEEq': {'EKCqb': 43, 'eJpVB': 57},
#                                'ePQIU': {'eYVCv': 46, 'hBwWf': 93, 'wHbQl': 85},
#                                'uAINm': {'BAdsc': 65,
#                                          'QVgvm': 10,
#                                          'TNxDs': 1,
#                                          'sFOIV': 71,
#                                          'uIAnG': 98}},
#                      'oajvO': {'HtOMA': {'AcsLB': 43, 'bbXPq': 41},
#                                'bxsTL': {'EDpKW': 23,
#                                          'KAbYv': 68,
#                                          'WHqib': 38,
#                                          'oTdlu': 39,
#                                          'zCsDR': 25},
#                                'lOKhL': {'JeOIx': 57,
#                                          'ReVUe': 5,
#                                          'bJJqu': 65,
#                                          'iQXVd': 50,
#                                          'ibxRe': 92}}},
#            'fZxsy': {'nfEJq': {'IUuOW': {'OzXGM': 45, 'yZkwX': 15},
#                                'nxNNw': {'DnIkv': 30, 'eLAux': 5},
#                                'otgkV': {'kGHHi': 21, 'tUDAY': 50}},
#                      'vwBud': {'Bcdpl': {'bXoHG': 76, 'wwodQ': 67},
#                                'jKntj': {'GRpKH': 38,
#                                          'UUXML': 55,
#                                          'hsVhr': 95,
#                                          'nhThv': 37,
#                                          'yotBG': 57},
#                                'ptOTJ': {'KtxRe': 24, 'qTuwe': 47},
#                                'xhRek': {'ELOag': 71,
#                                          'IZlRh': 67,
#                                          'JqEZc': 89,
#                                          'yNpts': 8}}},
#            'tPGRW': {'AWQGj': {'ZSlyn': {'oNCjE': 48, 'ouuDP': 56},
#                                'ftflZ': {'OLuYI': 91,
#                                          'dhYDs': 15,
#                                          'xPBJo': 68,
#                                          'xsMpt': 98,
#                                          'ydqBY': 65},
#                                'gKgFl': {'AgQxU': 92, 'DQzvc': 38, 'jcwRN': 34},
#                                'sclLN': {'dFEHa': 8, 'zTcfX': 31}},
#                      'EZmqE': {'EIFdz': {'CBNkH': 73,
#                                          'DHqyz': 50,
#                                          'QUsJk': 91,
#                                          'lJamj': 15},
#                                'eytgB': {'eFNuv': 13, 'nzjBk': 78},
#                                'hMFBG': {'QyDsb': 41,
#                                          'ZHglM': 78,
#                                          'ZRcrl': 24,
#                                          'rSpAx': 53,
#                                          'tyElE': 32},
#                                'hMpbN': {'BPLYF': 47,
#                                          'UbBaJ': 15,
#                                          'WnfhQ': 20,
#                                          'uFvtU': 5},
#                                'svqBk': {'AvTlW': 44,
#                                          'FKDeM': 2,
#                                          'PLuEE': 49,
#                                          'owxQm': 8}},
#                      'WFAlS': {'Nrgkj': {'FsGNK': 38, 'aCKOf': 72},
#                                'mPvyH': {'RJqjt': 52,
#                                          'RfVTm': 1,
#                                          'nmgNc': 26,
#                                          'ueqVG': 78}},
#                      'iUGnG': {'MtzlQ': {'FAayi': 13, 'zyraP': 10},
#                                'byIok': {'Qahor': 88, 'wWPFT': 99}},
#                      'meoSn': {'ZoYWf': {'MJLzE': 6, 'qOaMX': 74, 'rTWdA': 94},
#                                'nBZHb': {'CdzKW': 40,
#                                          'DhhpA': 20,
#                                          'KJQVN': 11}}},
#            'uvfSv': {'JjvRb': {'Mljca': {'BaaXH': 98,
#                                          'TNKtm': 69,
#                                          'UrlkF': 96,
#                                          'YuiAk': 68,
#                                          'qfgmm': 25},
#                                'VGqyH': {'EXsDm': 38,
#                                          'HMrXg': 35,
#                                          'QKcxI': 20,
#                                          'hSDKK': 78,
#                                          'jpEas': 27},
#                                'ZlkiM': {'ZCRSi': 80,
#                                          'dQCaA': 7,
#                                          'sqerJ': 89,
#                                          'viOEd': 32},
#                                'bJfoz': {'LuDYU': 65,
#                                          'ZOraG': 88,
#                                          'iSzEG': 99,
#                                          'wHvqJ': 42}},
#                      'TUNQZ': {'Xzfcs': {'HipAb': 19, 'oJnmg': 44},
#                                'ZswhH': {'UfMnP': 65, 'VZHaa': 48, 'plyGl': 22},
#                                'dqRoA': {'RfMbV': 79, 'lPfoB': 97}},
#                      'YoXUv': {'FScCk': {'kPzHn': 82, 'oQdTM': 98, 'wPFyk': 66},
#                                'LeBpX': {'CUlEP': 54,
#                                          'PKaDM': 85,
#                                          'omQRd': 64,
#                                          'rIseh': 7},
#                                'SphGf': {'MbTCl': 11, 'hZVDP': 28},
#                                'UfzIg': {'CitWF': 98, 'VtQCB': 92, 'XPzVI': 13},
#                                'ZExRO': {'FtjQH': 33,
#                                          'JRyHU': 15,
#                                          'PYcYa': 37}}}},
#  'ZRgIm': {'FVTCs': {'IRtZQ': {'gFPjy': {'KQKHr': 67, 'PTAcr': 2, 'unuUC': 78},
#                                'iIMLd': {'Ltplb': 41, 'gEnPE': 70},
#                                'rnvTe': {'fmjHz': 98,
#                                          'gERle': 57,
#                                          'jZwxI': 57,
#                                          'rKgaY': 100,
#                                          'vtzkh': 6}},
#                      'hWEwP': {'FLngD': {'KaSpi': 90, 'nIXpi': 21},
#                                'LPKQP': {'LzNdP': 81, 'gkoDJ': 93},
#                                'QVPts': {'UusDh': 39,
#                                          'adzhF': 74,
#                                          'dHMgl': 10,
#                                          'nddqf': 47},
#                                'nnVEM': {'KsWEF': 28,
#                                          'MVmWI': 20,
#                                          'qxetU': 7,
#                                          'sYYqK': 44,
#                                          'ymjeG': 39}},
#                      'sCRGP': {'UTvzU': {'YyMJK': 33,
#                                          'mWWWJ': 1,
#                                          'wCgVE': 74,
#                                          'ybAoq': 59,
#                                          'zRyKZ': 46},
#                                'aJJsz': {'lGeoK': 55, 'yHJXl': 44},
#                                'stNzk': {'DncsS': 46,
#                                          'PHZcC': 72,
#                                          'cpSbP': 59,
#                                          'pgEpd': 53,
#                                          'ppjAP': 16}},
#                      'tijxO': {'LIphm': {'XmYXr': 38, 'pELQM': 36, 'uJAUA': 65},
#                                'Pchuu': {'YLByv': 30, 'imbip': 32, 'vRlnV': 98},
#                                'XqvHD': {'RbgGB': 93,
#                                          'Robsw': 83,
#                                          'rqqUF': 63,
#                                          'zVrar': 49},
#                                'YDDQb': {'IGucS': 3,
#                                          'LfBgc': 3,
#                                          'imFZq': 58,
#                                          'xzBKW': 11},
#                                'bysjY': {'GQLCc': 77,
#                                          'HryPw': 32,
#                                          'aRaHv': 46,
#                                          'uMCLK': 82}}},
#            'cCHBk': {'KRoZr': {'EZEPQ': {'KYOTP': 18, 'pBNpK': 82},
#                                'ExhDD': {'LcmrP': 34, 'RbZGs': 99, 'xUUEy': 45},
#                                'bvruD': {'DqHVN': 57,
#                                          'YjhPr': 71,
#                                          'pOrty': 78,
#                                          'tCdot': 94,
#                                          'vYILd': 35},
#                                'cBwju': {'ItevN': 78,
#                                          'XfCus': 66,
#                                          'ZIRwG': 83,
#                                          'tPbuU': 73}},
#                      'lZQad': {'BCblr': {'YMrCP': 51, 'qJtyw': 64, 'tvHLK': 97},
#                                'WQAhI': {'YBecG': 76, 'YfrRf': 27, 'cUysS': 47},
#                                'jQqhi': {'Ccsvh': 72,
#                                          'XKchT': 13,
#                                          'lMiml': 100},
#                                'neqVX': {'Kerrm': 81,
#                                          'Qvpyy': 14,
#                                          'dUZPh': 93,
#                                          'fnUKF': 76},
#                                'vxQCi': {'RysgV': 69,
#                                          'iySBc': 33,
#                                          'rTVBE': 95}},
#                      'wFazz': {'PhWig': {'YjbCQ': 78, 'dwByJ': 22, 'mqCAy': 42},
#                                'lhIjd': {'KMhew': 51,
#                                          'MrkIl': 10,
#                                          'YELRM': 11,
#                                          'cgBYH': 36,
#                                          'mIgdy': 84}},
#                      'xEacu': {'rPnBu': {'FMSBZ': 10, 'FwsfS': 92, 'kwFBJ': 7},
#                                'ydSMv': {'Iiwcq': 84,
#                                          'fGWEK': 94,
#                                          'hWCzh': 71,
#                                          'lNxvd': 42,
#                                          'xJpxL': 85}}},
#            'dKIUe': {'ARgmh': {'DjQwx': {'PrCdG': 59,
#                                          'ZieYn': 73,
#                                          'gajnD': 72,
#                                          'phJbp': 57},
#                                'FxbEk': {'JikAr': 35,
#                                          'NDJPn': 45,
#                                          'TnUKw': 92,
#                                          'UABat': 33,
#                                          'wHbWV': 14},
#                                'QRAeh': {'AzDeM': 8, 'NuJPn': 24},
#                                'XQcGa': {'BrroR': 48, 'IHzGF': 60, 'UIqld': 19},
#                                'tmzGN': {'UZdIz': 31,
#                                          'mjexP': 82,
#                                          'sXKxH': 26,
#                                          'zigEa': 34}},
#                      'HxkRO': {'BpPFl': {'ROOPB': 96,
#                                          'SEZTD': 91,
#                                          'Vtvwt': 54,
#                                          'niVqV': 29},
#                                'JODvm': {'Dtkvx': 77,
#                                          'rUoIK': 52,
#                                          'rxJIQ': 3,
#                                          'uFKRu': 94,
#                                          'zGYVL': 10},
#                                'crmby': {'IwTWy': 78, 'LkaoE': 51, 'iFpVF': 37},
#                                'sLGnb': {'gNawF': 54, 'vypzd': 9}},
#                      'RcNYj': {'BVWAp': {'Pasia': 20,
#                                          'UWhLh': 55,
#                                          'dSWJa': 64,
#                                          'mkkwR': 98},
#                                'FXuXk': {'EOeMW': 96, 'mxbOW': 13, 'yPFlF': 64},
#                                'TWNaA': {'ekyFI': 53, 'kcbdv': 42, 'zWNCc': 57},
#                                'WryGH': {'eyoax': 65, 'qXLdl': 62, 'xvEzw': 67},
#                                'mxBPY': {'uPUGk': 43, 'zlVBy': 66}}},
#            'gIYSS': {'KblTg': {'BqyBa': {'EnOdn': 52, 'UXrsC': 50, 'XuAfl': 56},
#                                'GWukF': {'YERcz': 14, 'vKIyO': 37},
#                                'PTwBh': {'CVoGK': 26,
#                                          'GtjTs': 95,
#                                          'OFVoJ': 36,
#                                          'ZBbZQ': 8,
#                                          'gAfZl': 50},
#                                'meUsf': {'BeccZ': 38,
#                                          'SxCzo': 37,
#                                          'XSvpA': 58,
#                                          'jOOFS': 74,
#                                          'xTGzN': 71},
#                                'wCMxN': {'fbiMo': 95,
#                                          'kYkvZ': 44,
#                                          'rjgrr': 81}},
#                      'RATFf': {'DTJPX': {'FOTGE': 53,
#                                          'HnSLz': 25,
#                                          'fNyeL': 100,
#                                          'jLduy': 7,
#                                          'mEwnk': 78},
#                                'qOZNI': {'quvDG': 85,
#                                          'shOxL': 38,
#                                          'stIrx': 44}},
#                      'pHthP': {'WnOSE': {'EjOaZ': 51, 'OIDUS': 70},
#                                'xKTqL': {'AEYMx': 85, 'qmjhc': 26}}},
#            'qXmbA': {'DhFDn': {'AOGPL': {'aPAWu': 62,
#                                          'fjfUC': 5,
#                                          'hLCfd': 21,
#                                          'iNcPU': 74,
#                                          'mSkeh': 78},
#                                'Abrjm': {'iGsgF': 69, 'qGwOs': 27, 'zihnj': 40},
#                                'gakLB': {'NeFcF': 98,
#                                          'PWqNq': 11,
#                                          'bYZPR': 33,
#                                          'drOSf': 90},
#                                'tVdcC': {'PLlEG': 26,
#                                          'TPLjg': 73,
#                                          'odYtH': 57,
#                                          'yDvXJ': 31,
#                                          'zpWEb': 88},
#                                'xRACU': {'MtsiS': 61,
#                                          'QodWF': 67,
#                                          'mGFRa': 41,
#                                          'tUiNv': 71,
#                                          'zdUez': 46}},
#                      'SDxmA': {'TNjRB': {'saaZl': 49, 'ytuXY': 15},
#                                'ZrebV': {'AmDOx': 4,
#                                          'KnKAk': 41,
#                                          'oVZaa': 11,
#                                          'wBowW': 35,
#                                          'xtgHK': 33},
#                                'gdPVK': {'FkVTK': 67,
#                                          'OMIOM': 49,
#                                          'OiFnW': 65,
#                                          'acYtY': 51,
#                                          'qaWsL': 31},
#                                'nimvU': {'CpRdv': 67,
#                                          'IpkpD': 28,
#                                          'Yshvu': 2,
#                                          'rRdVj': 17,
#                                          'xnNeW': 10}}}},
#  'oTGBZ': {'VAeRB': {'QAqib': {'GuAGV': {'CwIBO': 42,
#                                          'bPaex': 39,
#                                          'toBOW': 40,
#                                          'uDbXo': 44,
#                                          'utOOM': 12},
#                                'jzlGT': {'KOwkm': 91, 'xUUAm': 7},
#                                'mpJMX': {'LBdYN': 12,
#                                          'MqGFE': 68,
#                                          'eYIZk': 4,
#                                          'kXTMP': 97,
#                                          'rfkdH': 44},
#                                'pMQTR': {'AJnDD': 42,
#                                          'HXUWK': 9,
#                                          'cshcY': 67,
#                                          'qNOHA': 12,
#                                          'xNCDM': 89},
#                                'sLMua': {'BXDCX': 63, 'ymUvN': 91}},
#                      'dJQYO': {'KzXDG': {'BFQLl': 16, 'cgbJD': 62, 'wqqaq': 53},
#                                'hDfzu': {'hDuHN': 77, 'mDMIw': 32, 'xKMxu': 4},
#                                'pZhyP': {'LxUSD': 95,
#                                          'MrzTr': 67,
#                                          'axzFf': 2,
#                                          'dfOtU': 20},
#                                'uibFE': {'Ayzxf': 73,
#                                          'dUkpj': 65,
#                                          'mWdYL': 51,
#                                          'owtaE': 27,
#                                          'zKMKh': 78}},
#                      'ebFPv': {'FcVAH': {'iHVhp': 24,
#                                          'nwtRO': 55,
#                                          'sAlIh': 85,
#                                          'vwTYj': 35,
#                                          'yHVRT': 96},
#                                'FusxR': {'XRQxl': 47, 'flLcm': 69, 'gmAWz': 44},
#                                'RmagB': {'RexpW': 67, 'TzYDY': 79, 'munxa': 34},
#                                'TERtP': {'Cvoxp': 84, 'zfVFP': 62},
#                                'ojWax': {'NuRXZ': 26,
#                                          'YKscD': 46,
#                                          'coJtr': 85,
#                                          'sxpcT': 32}},
#                      'egyGX': {'AOVdc': {'FHZBW': 90,
#                                          'Rleme': 40,
#                                          'dkMXV': 14,
#                                          'gHrsN': 58},
#                                'PPsWY': {'FVqvP': 80, 'izRPY': 74, 'wOQFx': 44},
#                                'crjxe': {'Khpjw': 31,
#                                          'hSDUf': 14,
#                                          'iWLlm': 71,
#                                          'oMdph': 11},
#                                'qetDo': {'BktMX': 19,
#                                          'CzBeD': 12,
#                                          'TdfNU': 95,
#                                          'balGW': 83}},
#                      'fJbXW': {'enJSc': {'AwcFj': 57,
#                                          'PjTJy': 99,
#                                          'SCpuO': 54,
#                                          'YCIZk': 87,
#                                          'aUlif': 35},
#                                'nOAXu': {'VrZrF': 8, 'WHxUB': 68, 'XsTsi': 7},
#                                'oAyjW': {'OljDG': 17, 'iGxNK': 62},
#                                'xogEH': {'cNRyT': 100, 'kExJp': 64}}},
#            'cLBZh': {'QWVVJ': {'CqMlz': {'Hgesu': 19, 'WFMww': 65, 'bMPVQ': 51},
#                                'PKBGp': {'SqeYF': 49, 'hVBYt': 56, 'vxsun': 77},
#                                'vueZU': {'RlpKJ': 68,
#                                          'dFxuE': 95,
#                                          'jHinJ': 2,
#                                          'xvJhJ': 51}},
#                      'RcEQb': {'HohmN': {'FYGdX': 97, 'aUKOT': 52},
#                                'SLuzs': {'FSaXZ': 40, 'WYfuT': 95, 'XkHpI': 62},
#                                'pCJvq': {'VEKxk': 11,
#                                          'XNFlk': 65,
#                                          'mzzKy': 93}},
#                      'nrQBj': {'Hxobz': {'GFxsx': 75,
#                                          'MzOqy': 49,
#                                          'TPxPs': 39,
#                                          'ZGCEI': 1,
#                                          'uXyII': 49},
#                                'sZYUg': {'Fhmsj': 56, 'YGXLr': 49, 'eTkMA': 78},
#                                'wCLWp': {'IqSab': 53,
#                                          'JEmVe': 74,
#                                          'mifKS': 52,
#                                          'wnIgH': 71},
#                                'yVgxn': {'ElHcD': 35, 'QoVdf': 47, 'oWWml': 9}},
#                      'pKNzl': {'PeMHx': {'AlkvB': 25,
#                                          'LMHOv': 2,
#                                          'Mwopz': 22,
#                                          'Rvybo': 91,
#                                          'gXHRb': 55},
#                                'ayfWH': {'GsEmF': 70,
#                                          'OLXNc': 66,
#                                          'bUmST': 79,
#                                          'bpLAQ': 68},
#                                'ditLV': {'BNNwW': 47,
#                                          'HZeJF': 62,
#                                          'OjJKG': 17,
#                                          'hGdMy': 82,
#                                          'lKmwT': 69},
#                                'yIVce': {'USHFL': 3,
#                                          'XJFgj': 56,
#                                          'uAAPB': 94}}},
#            'gSKhj': {'BUgkS': {'FJYoU': {'gHmpc': 11, 'jaxYo': 81},
#                                'RBvbK': {'TwuNe': 63,
#                                          'WobCY': 52,
#                                          'hAHDW': 23,
#                                          'oitCB': 89,
#                                          'ysBFl': 69},
#                                'ZTrsg': {'FRZNZ': 84,
#                                          'JCMwL': 70,
#                                          'PbxEQ': 34,
#                                          'XZCsy': 97,
#                                          'rXlqr': 24}},
#                      'WVPGw': {'BPsAN': {'BjFuS': 56, 'InRnD': 95, 'moosn': 11},
#                                'ioTuM': {'BDjNa': 44, 'VxqBj': 83}},
#                      'lxppD': {'mMeIk': {'FCvjP': 99, 'KuPaa': 15},
#                                'qgioA': {'CrIkP': 81,
#                                          'POadQ': 82,
#                                          'eKWEb': 48,
#                                          'kLnxo': 35,
#                                          'yXiio': 20}},
#                      'reFgO': {'EHVLB': {'BMEXH': 17,
#                                          'GJqga': 88,
#                                          'hihph': 22,
#                                          'odKAC': 2,
#                                          'pGFpu': 25},
#                                'zbwwu': {'YOVRV': 94,
#                                          'gsYQa': 88,
#                                          'hUVBL': 91,
#                                          'vxMvD': 8,
#                                          'yQaZM': 16}},
#                      'wXuGq': {'AbuES': {'UouSC': 5,
#                                          'aQAQx': 45,
#                                          'ahKSl': 37,
#                                          'yDeZX': 70},
#                                'qOOwE': {'NjbWP': 5,
#                                          'PasHD': 88,
#                                          'TlWte': 34,
#                                          'wLrRQ': 93},
#                                'sxBKl': {'CUgat': 97,
#                                          'YBZWM': 34,
#                                          'izkTF': 38,
#                                          'zjHBz': 28},
#                                'wRlbR': {'ZiSDN': 20,
#                                          'hFiMe': 78,
#                                          'jGIAs': 19}}}},
#  'rbZIp': {'DSFyz': {'XBxFj': {'OuIRK': {'BWRqF': 20, 'LliOn': 6, 'UKQJK': 27},
#                                'hJtgG': {'VIxXE': 91, 'baHRJ': 96},
#                                'nNuGc': {'FoHJz': 17,
#                                          'KaazL': 29,
#                                          'Ugyup': 68,
#                                          'pxBjb': 34,
#                                          'rRzkt': 17},
#                                'nnJHz': {'aWEbw': 92,
#                                          'tNDfx': 94,
#                                          'uLYFc': 43,
#                                          'whHdj': 79,
#                                          'zEeos': 69}},
#                      'bDmtC': {'QZNln': {'EWyxK': 60,
#                                          'SlGsL': 43,
#                                          'VgDkt': 85,
#                                          'dAeuk': 38},
#                                'RwEeT': {'Bagfd': 57,
#                                          'EwilD': 24,
#                                          'kwvCI': 99,
#                                          'nAxxO': 70},
#                                'gXJdc': {'JCyXl': 45,
#                                          'KnAuG': 8,
#                                          'uqSIw': 90,
#                                          'zAEON': 100},
#                                'koHii': {'LqyNS': 70,
#                                          'NMQrw': 22,
#                                          'NOvTq': 84,
#                                          'WDFJq': 68,
#                                          'hLNDe': 36},
#                                'rNrkL': {'bITjU': 38,
#                                          'bawmz': 98,
#                                          'nQcJy': 62,
#                                          'wyqmu': 45}},
#                      'htppc': {'gNvpf': {'PjJet': 51, 'YvVMg': 71},
#                                'vUFQT': {'KiTih': 16,
#                                          'WkPju': 1,
#                                          'XvVUJ': 35,
#                                          'aOQmz': 90},
#                                'zgqSF': {'Jmenm': 97,
#                                          'aJczQ': 50,
#                                          'zwHIp': 21}}},
#            'PyWQj': {'yqawI': {'dQDiW': {'BtGyl': 77,
#                                          'IYSwP': 89,
#                                          'ougAj': 27,
#                                          'ppApl': 33},
#                                'wcwlu': {'BkRLm': 45, 'ONqbq': 11, 'UJAyN': 4}},
#                      'zDWnQ': {'TTINw': {'YqkxJ': 16, 'dWvlv': 68},
#                                'VbXVb': {'KsFRb': 21,
#                                          'Xipyd': 59,
#                                          'atlUm': 36,
#                                          'bXSUo': 83,
#                                          'folPY': 71},
#                                'cuMMR': {'NCcnl': 26, 'yxfht': 32}}},
#            'iAPOs': {'yIZvG': {'gjJec': {'CZfHU': 89,
#                                          'FqKdm': 1,
#                                          'UtcWw': 15,
#                                          'ZZNwy': 28,
#                                          'ilkVr': 94},
#                                'gwCzM': {'OTbGe': 8, 'qMEYS': 22, 'vPGPG': 18},
#                                'kCqhs': {'DAcVu': 63,
#                                          'IAjSF': 99,
#                                          'aFiEz': 46,
#                                          'yGXBW': 44}},
#                      'yMNyI': {'KqAHg': {'GUPIK': 82,
#                                          'bWEDb': 33,
#                                          'oRfIC': 32,
#                                          'oUEtk': 50,
#                                          'vfeNv': 19},
#                                'QvBeN': {'LeRqj': 92,
#                                          'WgizZ': 5,
#                                          'wJeTi': 19,
#                                          'ykdpn': 29},
#                                'acUFK': {'Dsygp': 97, 'jeUtB': 41, 'snsRV': 24},
#                                'pygnQ': {'GQpJx': 6,
#                                          'vsehe': 51,
#                                          'ybeGx': 33}}}},
#  'rgOes': {'WUXsq': {'NhoJC': {'fQdYm': {'gSJzu': 83, 'hhjRX': 29},
#                                'kvvxW': {'CbmaJ': 62,
#                                          'VfsWU': 79,
#                                          'hnRHR': 48,
#                                          'oWhiN': 25,
#                                          'rwUNr': 86}},
#                      'NiFGc': {'ITEXm': {'EhHuc': 28, 'GJykc': 4, 'deWfz': 3},
#                                'XHGBP': {'uSyKO': 15, 'vHkdv': 62},
#                                'gGdxY': {'QBmBW': 87,
#                                          'QyKZj': 26,
#                                          'Sbfrq': 33,
#                                          'dHGsY': 72},
#                                'lDyDN': {'QfkCK': 2,
#                                          'RtbGC': 98,
#                                          'SzZlx': 93,
#                                          'jRAXc': 99}},
#                      'awzYk': {'PciLn': {'CgvNN': 64,
#                                          'EqAsF': 85,
#                                          'HbcDL': 69,
#                                          'Ihdvc': 5,
#                                          'XYtuZ': 14},
#                                'QalaI': {'BKXTM': 37,
#                                          'KyPQj': 47,
#                                          'NKcFi': 50,
#                                          'bJQLM': 73,
#                                          'nnfCZ': 73},
#                                'mAOhH': {'DErQK': 32,
#                                          'DvqBY': 61,
#                                          'gJJAZ': 31,
#                                          'viTXa': 97}}},
#            'feSZw': {'ArMzg': {'ABJpH': {'AFTQr': 1,
#                                          'XKkwg': 18,
#                                          'bOPTQ': 12,
#                                          'lPyDu': 35,
#                                          'prADD': 63},
#                                'QzjWj': {'RkQdF': 42, 'xCbWl': 83, 'ymznd': 25},
#                                'aAmmX': {'MIkXc': 31,
#                                          'asbYS': 79,
#                                          'shkfE': 91}},
#                      'VliOx': {'WPgtV': {'hONrW': 63, 'qYeuf': 60},
#                                'zPhhK': {'Avpzg': 9,
#                                          'aEDFu': 40,
#                                          'qBvsf': 20,
#                                          'vLtvi': 24}},
#                      'WmAlP': {'IrBns': {'NmdtQ': 57,
#                                          'YXQdB': 23,
#                                          'duxJM': 17,
#                                          'fBFWw': 93},
#                                'OAvwC': {'StGmW': 14, 'mNCwH': 79},
#                                'TWDbd': {'RUMjb': 24,
#                                          'mespW': 63,
#                                          'qPOqh': 51,
#                                          'varKA': 19},
#                                'saPib': {'HTdtI': 8, 'MnzYh': 66}}}}}

# %%
json_test1 = {
    'x': {"a": 1, 
          "b": {"ba": 1.2, 
                "bb": 2.2, 
                "bc": 2.3, 
                "bd": 2.4}, 
          "c": 2},
    'y': 3,
    'z': {"c": 4, 
          "d": 5},
    't': {"e": {"f": 6, 
                "g": 7, 
                "h": 8}, 
          "i": [9, 10, 11, 12]}
}

# %%
pprint.pprint(json_test1)
# Out:
# {'t': {'e': {'f': 6, 'g': 7, 'h': 8}, 'i': [9, 10, 11, 12]},
#  'x': {'a': 1, 'b': {'ba': 1.2, 'bb': 2.2, 'bc': 2.3, 'bd': 2.4}, 'c': 2},
#  'y': 3,
#  'z': {'c': 4, 'd': 5}}

# %%
article_json_test2 = {
    '@context': 'https://schema.org',
 '@type': 'NewsArticle',
 'articleBody': 'Nuevo incidente con una embarcación pesquera española en las '
                'aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC '
                'el gerente de la Organización de Productores Pesqueros '
                'Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de '
                'otro pesquero con base en La Línea de la Concepción (Cádiz) '
                'que acudió a este caladero para capturar melva «y cuando '
                'llegó ya lo estaban esperando los de Medio Ambiente de '
                'Gibraltar. Es más de lo mismo. Ha sido coaccionado y '
                'hostigado por intentar faenar donde siempre ».Es el segundo '
                'hostigamiento de las autoridades del Peñón a pesqueros '
                'andaluces. El pasado 21 de agosto, la Policía gibraltareña '
                'retuvo a un pesquero español y acusó a su patrón de graves '
                'delitos supuestamente cometidos en aguas que España reclama '
                'como propias según establece el Tratado de Utrecht. El '
                'pesquero pudo seguir su curso tras la denuncia '
                '.ReincidenciaEl nuevo incidente, apenas nueve días después, '
                'ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer '
                'poco después de las nueve de la mañana. El patrón, un español '
                'de 33 años, ha sido denunciado por agentes de la Sección '
                'Marítima de la Policía Real de Gibraltar asistidos por el '
                'Departamento de Medio Ambiente y la Sección Marítima del '
                'Servicio de Aduanas de la colonia británica. Nicolás '
                'Fernández condena lo que está ocurriendo, y recuerda que '
                'lleva produciéndose años porque Gibraltar considera que '
                'dichas aguas son de soberanía británica, algo que no reconoce '
                'España.Aunque el dirigente de la patronal pesquera agradece '
                'la protesta formulada por el Ministerio de Asuntos Exteriores '
                'a Reino Unido por estos hechos, considera que este conflicto '
                'debería haber sido resuelto «hace muchos años. Estas llamadas '
                'de atención por parte del Gobierno son necesarias pero este '
                'problema no es nuevo. No vamos a dejar de pelear, vamos a '
                'seguir poniendo de manifiesto que es un abuso de las '
                'autoridades de Gibraltar. O se sientan a establecer los '
                'límites de las aguas en las que pueden faenar los barcos '
                'nacionales o toman cartas en el asunto o tendrán que '
                'desplegar a las Fuerzas de Seguridad y al Ejército para que '
                'los pescadores puedan faenar», dijo.En ese sentido, Fernández '
                'anunció que hoy, viernes, mantendrá una reunión con el '
                'alcalde de La Línea de la Concepción, Juan Franco, un '
                'encuentro sobre el que no han querido adelantar '
                'acontecimientos ni el orden del día a tratar.Cabe recordar '
                'que desde este sector se exigió la semana pasada a los '
                'Gobiernos de España y del Peñón que se sentaran a establecer '
                'los límites de las aguas en las que pueden faenar los barcos '
                'nacionales, ante los repetidos incidentes que se están '
                'produciendo en esa zona. «Nosotros no vamos a dejar de '
                'pelear, vamos a seguir poniendo de manifiesto que es un abuso '
                'de las autoridades de Gibraltar», manifestaba Fernández '
                'entonces, advirtiendo que «o se sientan y toman cartas en el '
                'asunto, o tendrán que poner fuerzas de seguridad y al '
                'Ejército para que los pescadores puedan pescar».',
 'articleSection': 'andalucia',
 'author': [{'@type': 'Person',
             'memberOf': {'@context': 'https://schema.org',
                          '@type': 'NewsMediaOrganization',
                          'logo': {'@type': 'ImageObject',
                                   'height': 192,
                                   'url': 'https://s2.abcstatics.com/comun/2018/img/iconos-metas/favicon-192x192.png',
                                   'width': 192},
                          'name': 'ABC de Sevilla',
                          'url': 'https://sevilla.abc.es'},
             'name': 'Soraya Fernández',
             'url': 'https://sevilla.abc.es/autor/soraya-fernandez-6267/'}],
 'dateModified': '2023-09-01T04:23:30+02:00',
 'datePublished': '2023-09-01T04:23:30+02:00',
 'dateline': 'Spain',
 'description': '«Ha sido coaccionado y hostigado por intentar faenar donde '
                'siempre», dicen los pescadores',
 'headline': 'Gibraltar vuelve a impedir faenar a otro pesquero español',
 'image': {'@type': 'ImageObject',
           'height': '840',
           'url': 'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg',
           'width': '1200'},
 'inLanguage': 'es',
 'isAccessibleForFree': 'True',
 'isPartOf': {'@type': ['CreativeWork', 'Product'],
              'name': 'ABC de Sevilla',
              'productID': 'sevilla.abc.es:premium'},
 'keywords': ['Informaciones', 'Cádiz (Provincia)', 'ABC de Sevilla'],
 'mainEntityOfPage': {'@id': 'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html',
                      '@type': 'WebPage'},
 'publisher': {'@id': 'https://sevilla.abc.es/#publisher',
               '@type': 'Organization',
               'logo': {'@type': 'ImageObject',
                        'height': 60,
                        'url': 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png',
                        'width': 444},
               'name': 'ABC Andalucía',
               'sameAs': ['https://twitter.com/abcdesevilla/',
                          'https://www.facebook.com/abcdesevilla/',
                          'https://www.instagram.com/abcdesevilla/'],
               'url': 'https://sevilla.abc.es'},
 'speakable': {'@type': 'SpeakableSpecification',
               'xpath': ['/html/head/title',
                         "/html/head/meta[@name='description']/@content"]},
 'wordCount': '483'}

# %%
pprint.pprint(article_json_test2)
# Out:
# {'@context': 'https://schema.org',
#  '@type': 'NewsArticle',
#  'articleBody': 'Nuevo incidente con una embarcación pesquera española en las '
#                 'aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC '
#                 'el gerente de la Organización de Productores Pesqueros '
#                 'Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de '
#                 'otro pesquero con base en La Línea de la Concepción (Cádiz) '
#                 'que acudió a este caladero para capturar melva «y cuando '
#                 'llegó ya lo estaban esperando los de Medio Ambiente de '
#                 'Gibraltar. Es más de lo mismo. Ha sido coaccionado y '
#                 'hostigado por intentar faenar donde siempre ».Es el segundo '
#                 'hostigamiento de las autoridades del Peñón a pesqueros '
#                 'andaluces. El pasado 21 de agosto, la Policía gibraltareña '
#                 'retuvo a un pesquero español y acusó a su patrón de graves '
#                 'delitos supuestamente cometidos en aguas que España reclama '
#                 'como propias según establece el Tratado de Utrecht. El '
#                 'pesquero pudo seguir su curso tras la denuncia '
#                 '.ReincidenciaEl nuevo incidente, apenas nueve días después, '
#                 'ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer '
#                 'poco después de las nueve de la mañana. El patrón, un español '
#                 'de 33 años, ha sido denunciado por agentes de la Sección '
#                 'Marítima de la Policía Real de Gibraltar asistidos por el '
#                 'Departamento de Medio Ambiente y la Sección Marítima del '
#                 'Servicio de Aduanas de la colonia británica. Nicolás '
#                 'Fernández condena lo que está ocurriendo, y recuerda que '
#                 'lleva produciéndose años porque Gibraltar considera que '
#                 'dichas aguas son de soberanía británica, algo que no reconoce '
#                 'España.Aunque el dirigente de la patronal pesquera agradece '
#                 'la protesta formulada por el Ministerio de Asuntos Exteriores '
#                 'a Reino Unido por estos hechos, considera que este conflicto '
#                 'debería haber sido resuelto «hace muchos años. Estas llamadas '
#                 'de atención por parte del Gobierno son necesarias pero este '
#                 'problema no es nuevo. No vamos a dejar de pelear, vamos a '
#                 'seguir poniendo de manifiesto que es un abuso de las '
#                 'autoridades de Gibraltar. O se sientan a establecer los '
#                 'límites de las aguas en las que pueden faenar los barcos '
#                 'nacionales o toman cartas en el asunto o tendrán que '
#                 'desplegar a las Fuerzas de Seguridad y al Ejército para que '
#                 'los pescadores puedan faenar», dijo.En ese sentido, Fernández '
#                 'anunció que hoy, viernes, mantendrá una reunión con el '
#                 'alcalde de La Línea de la Concepción, Juan Franco, un '
#                 'encuentro sobre el que no han querido adelantar '
#                 'acontecimientos ni el orden del día a tratar.Cabe recordar '
#                 'que desde este sector se exigió la semana pasada a los '
#                 'Gobiernos de España y del Peñón que se sentaran a establecer '
#                 'los límites de las aguas en las que pueden faenar los barcos '
#                 'nacionales, ante los repetidos incidentes que se están '
#                 'produciendo en esa zona. «Nosotros no vamos a dejar de '
#                 'pelear, vamos a seguir poniendo de manifiesto que es un abuso '
#                 'de las autoridades de Gibraltar», manifestaba Fernández '
#                 'entonces, advirtiendo que «o se sientan y toman cartas en el '
#                 'asunto, o tendrán que poner fuerzas de seguridad y al '
#                 'Ejército para que los pescadores puedan pescar».',
#  'articleSection': 'andalucia',
#  'author': [{'@type': 'Person',
#              'memberOf': {'@context': 'https://schema.org',
#                           '@type': 'NewsMediaOrganization',
#                           'logo': {'@type': 'ImageObject',
#                                    'height': 192,
#                                    'url': 'https://s2.abcstatics.com/comun/2018/img/iconos-metas/favicon-192x192.png',
#                                    'width': 192},
#                           'name': 'ABC de Sevilla',
#                           'url': 'https://sevilla.abc.es'},
#              'name': 'Soraya Fernández',
#              'url': 'https://sevilla.abc.es/autor/soraya-fernandez-6267/'}],
#  'dateModified': '2023-09-01T04:23:30+02:00',
#  'datePublished': '2023-09-01T04:23:30+02:00',
#  'dateline': 'Spain',
#  'description': '«Ha sido coaccionado y hostigado por intentar faenar donde '
#                 'siempre», dicen los pescadores',
#  'headline': 'Gibraltar vuelve a impedir faenar a otro pesquero español',
#  'image': {'@type': 'ImageObject',
#            'height': '840',
#            'url': 'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg',
#            'width': '1200'},
#  'inLanguage': 'es',
#  'isAccessibleForFree': 'True',
#  'isPartOf': {'@type': ['CreativeWork', 'Product'],
#               'name': 'ABC de Sevilla',
#               'productID': 'sevilla.abc.es:premium'},
#  'keywords': ['Informaciones', 'Cádiz (Provincia)', 'ABC de Sevilla'],
#  'mainEntityOfPage': {'@id': 'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html',
#                       '@type': 'WebPage'},
#  'publisher': {'@id': 'https://sevilla.abc.es/#publisher',
#                '@type': 'Organization',
#                'logo': {'@type': 'ImageObject',
#                         'height': 60,
#                         'url': 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png',
#                         'width': 444},
#                'name': 'ABC Andalucía',
#                'sameAs': ['https://twitter.com/abcdesevilla/',
#                           'https://www.facebook.com/abcdesevilla/',
#                           'https://www.instagram.com/abcdesevilla/'],
#                'url': 'https://sevilla.abc.es'},
#  'speakable': {'@type': 'SpeakableSpecification',
#                'xpath': ['/html/head/title',
#                          "/html/head/meta[@name='description']/@content"]},
#  'wordCount': '483'}

# %%
only_keys1, keys_with_their_values1, trailed_keys1, returned_n_nestings1 = direct_recursive_destructure(article_json_test2)
returned_n_nestings1, len(only_keys1), len(keys_with_their_values1), len(trailed_keys1), len(keys_with_their_values1)
# Out:
# (1, 19, 40, 0, 40)

# %%
only_keys1
# Out:
# ['@context',
#  '@type',
#  'articleBody',
#  'articleSection',
#  'author',
#  'dateModified',
#  'datePublished',
#  'dateline',
#  'description',
#  'headline',
#  'image',
#  'inLanguage',
#  'isAccessibleForFree',
#  'isPartOf',
#  'keywords',
#  'mainEntityOfPage',
#  'publisher',
#  'speakable',
#  'wordCount']

# %%
keys_with_their_values1
# Out:
# [('@context', 'https://schema.org'),
#  ('@type', 'NewsArticle'),
#  ('articleBody',
#   'Nuevo incidente con una embarcación pesquera española en las aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC el gerente de la Organización de Productores Pesqueros Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de otro pesquero con base en La Línea de la Concepción (Cádiz) que acudió a este caladero para capturar melva «y cuando llegó ya lo estaban esperando los de Medio Ambiente de Gibraltar. Es más de lo mismo. Ha sido coaccionado y hostigado por intentar faenar donde siempre ».Es el segundo hostigamiento de las autoridades del Peñón a pesqueros andaluces. El pasado 21 de agosto, la Policía gibraltareña retuvo a un pesquero español y acusó a su patrón de graves delitos supuestamente cometidos en aguas que España reclama como propias según establece el Tratado de Utrecht. El pesquero pudo seguir su curso tras la denuncia .ReincidenciaEl nuevo incidente, apenas nueve días después, ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer poco después de las nueve de la mañana. El patrón, un español de 33 años, ha sido denunciado por agentes de la Sección Marítima de la Policía Real de Gibraltar asistidos por el Departamento de Medio Ambiente y la Sección Marítima del Servicio de Aduanas de la colonia británica. Nicolás Fernández condena lo que está ocurriendo, y recuerda que lleva produciéndose años porque Gibraltar considera que dichas aguas son de soberanía británica, algo que no reconoce España.Aunque el dirigente de la patronal pesquera agradece la protesta formulada por el Ministerio de Asuntos Exteriores a Reino Unido por estos hechos, considera que este conflicto debería haber sido resuelto «hace muchos años. Estas llamadas de atención por parte del Gobierno son necesarias pero este problema no es nuevo. No vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar. O se sientan a establecer los límites de las aguas en las que pueden faenar los barcos nacionales o toman cartas en el asunto o tendrán que desplegar a las Fuerzas de Seguridad y al Ejército para que los pescadores puedan faenar», dijo.En ese sentido, Fernández anunció que hoy, viernes, mantendrá una reunión con el alcalde de La Línea de la Concepción, Juan Franco, un encuentro sobre el que no han querido adelantar acontecimientos ni el orden del día a tratar.Cabe recordar que desde este sector se exigió la semana pasada a los Gobiernos de España y del Peñón que se sentaran a establecer los límites de las aguas en las que pueden faenar los barcos nacionales, ante los repetidos incidentes que se están produciendo en esa zona. «Nosotros no vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar», manifestaba Fernández entonces, advirtiendo que «o se sientan y toman cartas en el asunto, o tendrán que poner fuerzas de seguridad y al Ejército para que los pescadores puedan pescar».'),
#  ('articleSection', 'andalucia'),
#  ('author',
#   "[{'@type': 'Person', 'memberOf': {'@context': 'https://schema.org', '@type': 'NewsMediaOrganization', 'logo': {'@type': 'ImageObject', 'height': 192, 'url': 'https://s2.abcstatics.com/comun/2018/img/iconos-metas/favicon-192x192.png', 'width': 192}, 'name': 'ABC de Sevilla', 'url': 'https://sevilla.abc.es'}, 'name': 'Soraya Fernández', 'url': 'https://sevilla.abc.es/autor/soraya-fernandez-6267/'}]"),
#  ('dateModified', '2023-09-01T04:23:30+02:00'),
#  ('datePublished', '2023-09-01T04:23:30+02:00'),
#  ('dateline', 'Spain'),
#  ('description',
#   '«Ha sido coaccionado y hostigado por intentar faenar donde siempre», dicen los pescadores'),
#  ('headline', 'Gibraltar vuelve a impedir faenar a otro pesquero español'),
#  ('@type', 'ImageObject'),
#  ('height', '840'),
#  ('url',
#   'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg'),
#  ('width', '1200'),
#  ('image', ('@type', 'height', 'url', 'width')),
#  ('inLanguage', 'es'),
#  ('isAccessibleForFree', 'True'),
#  ('@type', "['CreativeWork', 'Product']"),
#  ('name', 'ABC de Sevilla'),
#  ('productID', 'sevilla.abc.es:premium'),
#  ('isPartOf', ('@type', 'name', 'productID')),
#  ('keywords', "['Informaciones', 'Cádiz (Provincia)', 'ABC de Sevilla']"),
#  ('@id',
#   'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html'),
#  ('@type', 'WebPage'),
#  ('mainEntityOfPage', ('@id', '@type')),
#  ('@id', 'https://sevilla.abc.es/#publisher'),
#  ('@type', 'Organization'),
#  ('@type', 'ImageObject'),
#  ('height', '60'),
#  ('url', 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png'),
#  ('width', '444'),
#  ('logo', ('@type', 'height', 'url', 'width')),
#  ('name', 'ABC Andalucía'),
#  ('sameAs',
#   "['https://twitter.com/abcdesevilla/', 'https://www.facebook.com/abcdesevilla/', 'https://www.instagram.com/abcdesevilla/']"),
#  ('url', 'https://sevilla.abc.es'),
#  ('publisher', ('@id', '@type', 'logo', 'name', 'sameAs', 'url')),
#  ('@type', 'SpeakableSpecification'),
#  ('xpath',
#   '[\'/html/head/title\', "/html/head/meta[@name=\'description\']/@content"]'),
#  ('speakable', ('@type', 'xpath')),
#  ('wordCount', '483')]

# %%
trailed_keys1
# Out:
# []

# %%
only_keys2, keys_values2, trailed_keys2, only_pairs2, n_nestings2, steps2 = indirect_recursive_json_destructure(article_json_test2)
print(n_nestings2, steps2, len(keys_values2), end="\n\n")
# Out:
# 3 86 27

# %%
# %timeit dir_recursive_json_destructure(article_json_test2)
# %timeit indir_recursive_json_destructure(article_json_test2)
# Out:
# 19.9 µs ± 271 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 54.8 µs ± 401 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
only_keys2
# Out:
# ['@context',
#  '@type',
#  'articleBody',
#  'articleSection',
#  'author',
#  'dateModified',
#  'datePublished',
#  'dateline',
#  'description',
#  'headline',
#  'image',
#  '@type',
#  'height',
#  'url',
#  'width',
#  '@type',
#  'name',
#  'productID',
#  '@id',
#  '@type',
#  '@id',
#  '@type',
#  'logo',
#  '@type',
#  'height',
#  'url',
#  'width',
#  '@type',
#  'xpath']

# %%
trailed_keys2
# Out:
# ['@context-@type-articleBody-articleSection-author-dateModified-datePublished-dateline-description-headline-image-@type-height-url-width',
#  '@type-name-productID',
#  '@id-@type',
#  '@id-@type-logo-@type-height-url-width',
#  '@type-xpath']

# %%
only_pairs2
# Out:
# [('@context', 'https://schema.org'),
#  ('@type', 'NewsArticle'),
#  ('articleBody',
#   'Nuevo incidente con una embarcación pesquera española en las aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC el gerente de la Organización de Productores Pesqueros Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de otro pesquero con base en La Línea de la Concepción (Cádiz) que acudió a este caladero para capturar melva «y cuando llegó ya lo estaban esperando los de Medio Ambiente de Gibraltar. Es más de lo mismo. Ha sido coaccionado y hostigado por intentar faenar donde siempre ».Es el segundo hostigamiento de las autoridades del Peñón a pesqueros andaluces. El pasado 21 de agosto, la Policía gibraltareña retuvo a un pesquero español y acusó a su patrón de graves delitos supuestamente cometidos en aguas que España reclama como propias según establece el Tratado de Utrecht. El pesquero pudo seguir su curso tras la denuncia .ReincidenciaEl nuevo incidente, apenas nueve días después, ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer poco después de las nueve de la mañana. El patrón, un español de 33 años, ha sido denunciado por agentes de la Sección Marítima de la Policía Real de Gibraltar asistidos por el Departamento de Medio Ambiente y la Sección Marítima del Servicio de Aduanas de la colonia británica. Nicolás Fernández condena lo que está ocurriendo, y recuerda que lleva produciéndose años porque Gibraltar considera que dichas aguas son de soberanía británica, algo que no reconoce España.Aunque el dirigente de la patronal pesquera agradece la protesta formulada por el Ministerio de Asuntos Exteriores a Reino Unido por estos hechos, considera que este conflicto debería haber sido resuelto «hace muchos años. Estas llamadas de atención por parte del Gobierno son necesarias pero este problema no es nuevo. No vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar. O se sientan a establecer los límites de las aguas en las que pueden faenar los barcos nacionales o toman cartas en el asunto o tendrán que desplegar a las Fuerzas de Seguridad y al Ejército para que los pescadores puedan faenar», dijo.En ese sentido, Fernández anunció que hoy, viernes, mantendrá una reunión con el alcalde de La Línea de la Concepción, Juan Franco, un encuentro sobre el que no han querido adelantar acontecimientos ni el orden del día a tratar.Cabe recordar que desde este sector se exigió la semana pasada a los Gobiernos de España y del Peñón que se sentaran a establecer los límites de las aguas en las que pueden faenar los barcos nacionales, ante los repetidos incidentes que se están produciendo en esa zona. «Nosotros no vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar», manifestaba Fernández entonces, advirtiendo que «o se sientan y toman cartas en el asunto, o tendrán que poner fuerzas de seguridad y al Ejército para que los pescadores puedan pescar».'),
#  ('articleSection', 'andalucia'),
#  ('dateModified', '2023-09-01T04:23:30+02:00'),
#  ('datePublished', '2023-09-01T04:23:30+02:00'),
#  ('dateline', 'Spain'),
#  ('description',
#   '«Ha sido coaccionado y hostigado por intentar faenar donde siempre», dicen los pescadores'),
#  ('headline', 'Gibraltar vuelve a impedir faenar a otro pesquero español'),
#  ('@type', 'ImageObject'),
#  ('height', '840'),
#  ('url',
#   'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg'),
#  ('width', '1200'),
#  ('name', 'ABC de Sevilla'),
#  ('productID', 'sevilla.abc.es:premium'),
#  ('@id',
#   'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html'),
#  ('@type', 'WebPage'),
#  ('@id', 'https://sevilla.abc.es/#publisher'),
#  ('@type', 'Organization'),
#  ('@type', 'ImageObject'),
#  ('height', 60),
#  ('url', 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png'),
#  ('width', 444),
#  ('@type', 'SpeakableSpecification')]

# %%
keys_with_their_values1
# Out:
# [('@context', 'https://schema.org'),
#  ('@type', 'NewsArticle'),
#  ('articleBody',
#   'Nuevo incidente con una embarcación pesquera española en las aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC el gerente de la Organización de Productores Pesqueros Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de otro pesquero con base en La Línea de la Concepción (Cádiz) que acudió a este caladero para capturar melva «y cuando llegó ya lo estaban esperando los de Medio Ambiente de Gibraltar. Es más de lo mismo. Ha sido coaccionado y hostigado por intentar faenar donde siempre ».Es el segundo hostigamiento de las autoridades del Peñón a pesqueros andaluces. El pasado 21 de agosto, la Policía gibraltareña retuvo a un pesquero español y acusó a su patrón de graves delitos supuestamente cometidos en aguas que España reclama como propias según establece el Tratado de Utrecht. El pesquero pudo seguir su curso tras la denuncia .ReincidenciaEl nuevo incidente, apenas nueve días después, ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer poco después de las nueve de la mañana. El patrón, un español de 33 años, ha sido denunciado por agentes de la Sección Marítima de la Policía Real de Gibraltar asistidos por el Departamento de Medio Ambiente y la Sección Marítima del Servicio de Aduanas de la colonia británica. Nicolás Fernández condena lo que está ocurriendo, y recuerda que lleva produciéndose años porque Gibraltar considera que dichas aguas son de soberanía británica, algo que no reconoce España.Aunque el dirigente de la patronal pesquera agradece la protesta formulada por el Ministerio de Asuntos Exteriores a Reino Unido por estos hechos, considera que este conflicto debería haber sido resuelto «hace muchos años. Estas llamadas de atención por parte del Gobierno son necesarias pero este problema no es nuevo. No vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar. O se sientan a establecer los límites de las aguas en las que pueden faenar los barcos nacionales o toman cartas en el asunto o tendrán que desplegar a las Fuerzas de Seguridad y al Ejército para que los pescadores puedan faenar», dijo.En ese sentido, Fernández anunció que hoy, viernes, mantendrá una reunión con el alcalde de La Línea de la Concepción, Juan Franco, un encuentro sobre el que no han querido adelantar acontecimientos ni el orden del día a tratar.Cabe recordar que desde este sector se exigió la semana pasada a los Gobiernos de España y del Peñón que se sentaran a establecer los límites de las aguas en las que pueden faenar los barcos nacionales, ante los repetidos incidentes que se están produciendo en esa zona. «Nosotros no vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar», manifestaba Fernández entonces, advirtiendo que «o se sientan y toman cartas en el asunto, o tendrán que poner fuerzas de seguridad y al Ejército para que los pescadores puedan pescar».'),
#  ('articleSection', 'andalucia'),
#  ('author',
#   "[{'@type': 'Person', 'memberOf': {'@context': 'https://schema.org', '@type': 'NewsMediaOrganization', 'logo': {'@type': 'ImageObject', 'height': 192, 'url': 'https://s2.abcstatics.com/comun/2018/img/iconos-metas/favicon-192x192.png', 'width': 192}, 'name': 'ABC de Sevilla', 'url': 'https://sevilla.abc.es'}, 'name': 'Soraya Fernández', 'url': 'https://sevilla.abc.es/autor/soraya-fernandez-6267/'}]"),
#  ('dateModified', '2023-09-01T04:23:30+02:00'),
#  ('datePublished', '2023-09-01T04:23:30+02:00'),
#  ('dateline', 'Spain'),
#  ('description',
#   '«Ha sido coaccionado y hostigado por intentar faenar donde siempre», dicen los pescadores'),
#  ('headline', 'Gibraltar vuelve a impedir faenar a otro pesquero español'),
#  ('@type', 'ImageObject'),
#  ('height', '840'),
#  ('url',
#   'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg'),
#  ('width', '1200'),
#  ('image', ('@type', 'height', 'url', 'width')),
#  ('inLanguage', 'es'),
#  ('isAccessibleForFree', 'True'),
#  ('@type', "['CreativeWork', 'Product']"),
#  ('name', 'ABC de Sevilla'),
#  ('productID', 'sevilla.abc.es:premium'),
#  ('isPartOf', ('@type', 'name', 'productID')),
#  ('keywords', "['Informaciones', 'Cádiz (Provincia)', 'ABC de Sevilla']"),
#  ('@id',
#   'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html'),
#  ('@type', 'WebPage'),
#  ('mainEntityOfPage', ('@id', '@type')),
#  ('@id', 'https://sevilla.abc.es/#publisher'),
#  ('@type', 'Organization'),
#  ('@type', 'ImageObject'),
#  ('height', '60'),
#  ('url', 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png'),
#  ('width', '444'),
#  ('logo', ('@type', 'height', 'url', 'width')),
#  ('name', 'ABC Andalucía'),
#  ('sameAs',
#   "['https://twitter.com/abcdesevilla/', 'https://www.facebook.com/abcdesevilla/', 'https://www.instagram.com/abcdesevilla/']"),
#  ('url', 'https://sevilla.abc.es'),
#  ('publisher', ('@id', '@type', 'logo', 'name', 'sameAs', 'url')),
#  ('@type', 'SpeakableSpecification'),
#  ('xpath',
#   '[\'/html/head/title\', "/html/head/meta[@name=\'description\']/@content"]'),
#  ('speakable', ('@type', 'xpath')),
#  ('wordCount', '483')]

# %% [markdown]
# ### Case with no list as value

# %%
article_json_test3 = {
    '@context': 'https://schema.org',
 '@type': 'NewsArticle',
 'articleBody': 'Nuevo incidente con una embarcación pesquera española en las '
                'aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC '
                'el gerente de la Organización de Productores Pesqueros '
                'Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de '
                'otro pesquero con base en La Línea de la Concepción (Cádiz) '
                'que acudió a este caladero para capturar melva «y cuando '
                'llegó ya lo estaban esperando los de Medio Ambiente de '
                'Gibraltar. Es más de lo mismo. Ha sido coaccionado y '
                'hostigado por intentar faenar donde siempre ».Es el segundo '
                'hostigamiento de las autoridades del Peñón a pesqueros '
                'andaluces. El pasado 21 de agosto, la Policía gibraltareña '
                'retuvo a un pesquero español y acusó a su patrón de graves '
                'delitos supuestamente cometidos en aguas que España reclama '
                'como propias según establece el Tratado de Utrecht. El '
                'pesquero pudo seguir su curso tras la denuncia '
                '.ReincidenciaEl nuevo incidente, apenas nueve días después, '
                'ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer '
                'poco después de las nueve de la mañana. El patrón, un español '
                'de 33 años, ha sido denunciado por agentes de la Sección '
                'Marítima de la Policía Real de Gibraltar asistidos por el '
                'Departamento de Medio Ambiente y la Sección Marítima del '
                'Servicio de Aduanas de la colonia británica. Nicolás '
                'Fernández condena lo que está ocurriendo, y recuerda que '
                'lleva produciéndose años porque Gibraltar considera que '
                'dichas aguas son de soberanía británica, algo que no reconoce '
                'España.Aunque el dirigente de la patronal pesquera agradece '
                'la protesta formulada por el Ministerio de Asuntos Exteriores '
                'a Reino Unido por estos hechos, considera que este conflicto '
                'debería haber sido resuelto «hace muchos años. Estas llamadas '
                'de atención por parte del Gobierno son necesarias pero este '
                'problema no es nuevo. No vamos a dejar de pelear, vamos a '
                'seguir poniendo de manifiesto que es un abuso de las '
                'autoridades de Gibraltar. O se sientan a establecer los '
                'límites de las aguas en las que pueden faenar los barcos '
                'nacionales o toman cartas en el asunto o tendrán que '
                'desplegar a las Fuerzas de Seguridad y al Ejército para que '
                'los pescadores puedan faenar», dijo.En ese sentido, Fernández '
                'anunció que hoy, viernes, mantendrá una reunión con el '
                'alcalde de La Línea de la Concepción, Juan Franco, un '
                'encuentro sobre el que no han querido adelantar '
                'acontecimientos ni el orden del día a tratar.Cabe recordar '
                'que desde este sector se exigió la semana pasada a los '
                'Gobiernos de España y del Peñón que se sentaran a establecer '
                'los límites de las aguas en las que pueden faenar los barcos '
                'nacionales, ante los repetidos incidentes que se están '
                'produciendo en esa zona. «Nosotros no vamos a dejar de '
                'pelear, vamos a seguir poniendo de manifiesto que es un abuso '
                'de las autoridades de Gibraltar», manifestaba Fernández '
                'entonces, advirtiendo que «o se sientan y toman cartas en el '
                'asunto, o tendrán que poner fuerzas de seguridad y al '
                'Ejército para que los pescadores puedan pescar».',
 'articleSection': 'andalucia',
 'author': {'@type': 'Person',
             'memberOf': {'@context': 'https://schema.org',
                          '@type': 'NewsMediaOrganization',
                          'logo': {'@type': 'ImageObject',
                                   'height': 192,
                                   'url': 'https://s2.abcstatics.com/comun/2018/img/iconos-metas/favicon-192x192.png',
                                   'width': 192},
                          'name': 'ABC de Sevilla',
                          'url': 'https://sevilla.abc.es'},
             'name': 'Soraya Fernández',
             'url': 'https://sevilla.abc.es/autor/soraya-fernandez-6267/'},
 'dateModified': '2023-09-01T04:23:30+02:00',
 'datePublished': '2023-09-01T04:23:30+02:00',
 'dateline': 'Spain',
 'description': '«Ha sido coaccionado y hostigado por intentar faenar donde '
                'siempre», dicen los pescadores',
 'headline': 'Gibraltar vuelve a impedir faenar a otro pesquero español',
 'image': {'@type': 'ImageObject',
           'height': '840',
           'url': 'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg',
           'width': '1200'},
 'inLanguage': 'es',
 'isAccessibleForFree': 'True',
 'isPartOf': {'@type': ['CreativeWork', 'Product'],
              'name': 'ABC de Sevilla',
              'productID': 'sevilla.abc.es:premium'},
 'keywords': ['Informaciones', 'Cádiz (Provincia)', 'ABC de Sevilla'],
 'mainEntityOfPage': {'@id': 'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html',
                      '@type': 'WebPage'},
 'publisher': {'@id': 'https://sevilla.abc.es/#publisher',
               '@type': 'Organization',
               'logo': {'@type': 'ImageObject',
                        'height': 60,
                        'url': 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png',
                        'width': 444},
               'name': 'ABC Andalucía',
               'sameAs': ['https://twitter.com/abcdesevilla/',
                          'https://www.facebook.com/abcdesevilla/',
                          'https://www.instagram.com/abcdesevilla/'],
               'url': 'https://sevilla.abc.es'},
 'speakable': {'@type': 'SpeakableSpecification',
               'xpath': ['/html/head/title',
                         "/html/head/meta[@name='description']/@content"]},
 'wordCount': '483'}
pprint.pprint(article_json_test3)
# Out:
# {'@context': 'https://schema.org',
#  '@type': 'NewsArticle',
#  'articleBody': 'Nuevo incidente con una embarcación pesquera española en las '
#                 'aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC '
#                 'el gerente de la Organización de Productores Pesqueros '
#                 'Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de '
#                 'otro pesquero con base en La Línea de la Concepción (Cádiz) '
#                 'que acudió a este caladero para capturar melva «y cuando '
#                 'llegó ya lo estaban esperando los de Medio Ambiente de '
#                 'Gibraltar. Es más de lo mismo. Ha sido coaccionado y '
#                 'hostigado por intentar faenar donde siempre ».Es el segundo '
#                 'hostigamiento de las autoridades del Peñón a pesqueros '
#                 'andaluces. El pasado 21 de agosto, la Policía gibraltareña '
#                 'retuvo a un pesquero español y acusó a su patrón de graves '
#                 'delitos supuestamente cometidos en aguas que España reclama '
#                 'como propias según establece el Tratado de Utrecht. El '
#                 'pesquero pudo seguir su curso tras la denuncia '
#                 '.ReincidenciaEl nuevo incidente, apenas nueve días después, '
#                 'ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer '
#                 'poco después de las nueve de la mañana. El patrón, un español '
#                 'de 33 años, ha sido denunciado por agentes de la Sección '
#                 'Marítima de la Policía Real de Gibraltar asistidos por el '
#                 'Departamento de Medio Ambiente y la Sección Marítima del '
#                 'Servicio de Aduanas de la colonia británica. Nicolás '
#                 'Fernández condena lo que está ocurriendo, y recuerda que '
#                 'lleva produciéndose años porque Gibraltar considera que '
#                 'dichas aguas son de soberanía británica, algo que no reconoce '
#                 'España.Aunque el dirigente de la patronal pesquera agradece '
#                 'la protesta formulada por el Ministerio de Asuntos Exteriores '
#                 'a Reino Unido por estos hechos, considera que este conflicto '
#                 'debería haber sido resuelto «hace muchos años. Estas llamadas '
#                 'de atención por parte del Gobierno son necesarias pero este '
#                 'problema no es nuevo. No vamos a dejar de pelear, vamos a '
#                 'seguir poniendo de manifiesto que es un abuso de las '
#                 'autoridades de Gibraltar. O se sientan a establecer los '
#                 'límites de las aguas en las que pueden faenar los barcos '
#                 'nacionales o toman cartas en el asunto o tendrán que '
#                 'desplegar a las Fuerzas de Seguridad y al Ejército para que '
#                 'los pescadores puedan faenar», dijo.En ese sentido, Fernández '
#                 'anunció que hoy, viernes, mantendrá una reunión con el '
#                 'alcalde de La Línea de la Concepción, Juan Franco, un '
#                 'encuentro sobre el que no han querido adelantar '
#                 'acontecimientos ni el orden del día a tratar.Cabe recordar '
#                 'que desde este sector se exigió la semana pasada a los '
#                 'Gobiernos de España y del Peñón que se sentaran a establecer '
#                 'los límites de las aguas en las que pueden faenar los barcos '
#                 'nacionales, ante los repetidos incidentes que se están '
#                 'produciendo en esa zona. «Nosotros no vamos a dejar de '
#                 'pelear, vamos a seguir poniendo de manifiesto que es un abuso '
#                 'de las autoridades de Gibraltar», manifestaba Fernández '
#                 'entonces, advirtiendo que «o se sientan y toman cartas en el '
#                 'asunto, o tendrán que poner fuerzas de seguridad y al '
#                 'Ejército para que los pescadores puedan pescar».',
#  'articleSection': 'andalucia',
#  'author': {'@type': 'Person',
#             'memberOf': {'@context': 'https://schema.org',
#                          '@type': 'NewsMediaOrganization',
#                          'logo': {'@type': 'ImageObject',
#                                   'height': 192,
#                                   'url': 'https://s2.abcstatics.com/comun/2018/img/iconos-metas/favicon-192x192.png',
#                                   'width': 192},
#                          'name': 'ABC de Sevilla',
#                          'url': 'https://sevilla.abc.es'},
#             'name': 'Soraya Fernández',
#             'url': 'https://sevilla.abc.es/autor/soraya-fernandez-6267/'},
#  'dateModified': '2023-09-01T04:23:30+02:00',
#  'datePublished': '2023-09-01T04:23:30+02:00',
#  'dateline': 'Spain',
#  'description': '«Ha sido coaccionado y hostigado por intentar faenar donde '
#                 'siempre», dicen los pescadores',
#  'headline': 'Gibraltar vuelve a impedir faenar a otro pesquero español',
#  'image': {'@type': 'ImageObject',
#            'height': '840',
#            'url': 'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg',
#            'width': '1200'},
#  'inLanguage': 'es',
#  'isAccessibleForFree': 'True',
#  'isPartOf': {'@type': ['CreativeWork', 'Product'],
#               'name': 'ABC de Sevilla',
#               'productID': 'sevilla.abc.es:premium'},
#  'keywords': ['Informaciones', 'Cádiz (Provincia)', 'ABC de Sevilla'],
#  'mainEntityOfPage': {'@id': 'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html',
#                       '@type': 'WebPage'},
#  'publisher': {'@id': 'https://sevilla.abc.es/#publisher',
#                '@type': 'Organization',
#                'logo': {'@type': 'ImageObject',
#                         'height': 60,
#                         'url': 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png',
#                         'width': 444},
#                'name': 'ABC Andalucía',
#                'sameAs': ['https://twitter.com/abcdesevilla/',
#                           'https://www.facebook.com/abcdesevilla/',
#                           'https://www.instagram.com/abcdesevilla/'],
#                'url': 'https://sevilla.abc.es'},
#  'speakable': {'@type': 'SpeakableSpecification',
#                'xpath': ['/html/head/title',
#                          "/html/head/meta[@name='description']/@content"]},
#  'wordCount': '483'}

# %%
only_keys3, keys_values3, trailed_keys3, only_pairs3, n_nestings3, steps3 = indirect_recursive_json_destructure(article_json_test3)
print(n_nestings3, steps3, len(keys_values3), end="\n\n")
# Out:
# 4 120 28

# %%
only_pairs3
# Out:
# [('@context', 'https://schema.org'),
#  ('@type', 'NewsArticle'),
#  ('articleBody',
#   'Nuevo incidente con una embarcación pesquera española en las aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC el gerente de la Organización de Productores Pesqueros Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de otro pesquero con base en La Línea de la Concepción (Cádiz) que acudió a este caladero para capturar melva «y cuando llegó ya lo estaban esperando los de Medio Ambiente de Gibraltar. Es más de lo mismo. Ha sido coaccionado y hostigado por intentar faenar donde siempre ».Es el segundo hostigamiento de las autoridades del Peñón a pesqueros andaluces. El pasado 21 de agosto, la Policía gibraltareña retuvo a un pesquero español y acusó a su patrón de graves delitos supuestamente cometidos en aguas que España reclama como propias según establece el Tratado de Utrecht. El pesquero pudo seguir su curso tras la denuncia .ReincidenciaEl nuevo incidente, apenas nueve días después, ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer poco después de las nueve de la mañana. El patrón, un español de 33 años, ha sido denunciado por agentes de la Sección Marítima de la Policía Real de Gibraltar asistidos por el Departamento de Medio Ambiente y la Sección Marítima del Servicio de Aduanas de la colonia británica. Nicolás Fernández condena lo que está ocurriendo, y recuerda que lleva produciéndose años porque Gibraltar considera que dichas aguas son de soberanía británica, algo que no reconoce España.Aunque el dirigente de la patronal pesquera agradece la protesta formulada por el Ministerio de Asuntos Exteriores a Reino Unido por estos hechos, considera que este conflicto debería haber sido resuelto «hace muchos años. Estas llamadas de atención por parte del Gobierno son necesarias pero este problema no es nuevo. No vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar. O se sientan a establecer los límites de las aguas en las que pueden faenar los barcos nacionales o toman cartas en el asunto o tendrán que desplegar a las Fuerzas de Seguridad y al Ejército para que los pescadores puedan faenar», dijo.En ese sentido, Fernández anunció que hoy, viernes, mantendrá una reunión con el alcalde de La Línea de la Concepción, Juan Franco, un encuentro sobre el que no han querido adelantar acontecimientos ni el orden del día a tratar.Cabe recordar que desde este sector se exigió la semana pasada a los Gobiernos de España y del Peñón que se sentaran a establecer los límites de las aguas en las que pueden faenar los barcos nacionales, ante los repetidos incidentes que se están produciendo en esa zona. «Nosotros no vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar», manifestaba Fernández entonces, advirtiendo que «o se sientan y toman cartas en el asunto, o tendrán que poner fuerzas de seguridad y al Ejército para que los pescadores puedan pescar».'),
#  ('articleSection', 'andalucia'),
#  ('@type', 'Person'),
#  ('@context', 'https://schema.org'),
#  ('@type', 'NewsMediaOrganization'),
#  ('@type', 'ImageObject'),
#  ('height', 192),
#  ('url',
#   'https://s2.abcstatics.com/comun/2018/img/iconos-metas/favicon-192x192.png'),
#  ('width', 192),
#  ('@type', 'ImageObject'),
#  ('height', '840'),
#  ('url',
#   'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg'),
#  ('width', '1200'),
#  ('name', 'ABC de Sevilla'),
#  ('productID', 'sevilla.abc.es:premium'),
#  ('@id',
#   'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html'),
#  ('@type', 'WebPage'),
#  ('@id', 'https://sevilla.abc.es/#publisher'),
#  ('@type', 'Organization'),
#  ('@type', 'ImageObject'),
#  ('height', 60),
#  ('url', 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png'),
#  ('width', 444),
#  ('@type', 'SpeakableSpecification')]

# %%
keys_values3
# Out:
# [('@context', 'https://schema.org'),
#  ('@type', 'NewsArticle'),
#  ('articleBody',
#   'Nuevo incidente con una embarcación pesquera española en las aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC el gerente de la Organización de Productores Pesqueros Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de otro pesquero con base en La Línea de la Concepción (Cádiz) que acudió a este caladero para capturar melva «y cuando llegó ya lo estaban esperando los de Medio Ambiente de Gibraltar. Es más de lo mismo. Ha sido coaccionado y hostigado por intentar faenar donde siempre ».Es el segundo hostigamiento de las autoridades del Peñón a pesqueros andaluces. El pasado 21 de agosto, la Policía gibraltareña retuvo a un pesquero español y acusó a su patrón de graves delitos supuestamente cometidos en aguas que España reclama como propias según establece el Tratado de Utrecht. El pesquero pudo seguir su curso tras la denuncia .ReincidenciaEl nuevo incidente, apenas nueve días después, ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer poco después de las nueve de la mañana. El patrón, un español de 33 años, ha sido denunciado por agentes de la Sección Marítima de la Policía Real de Gibraltar asistidos por el Departamento de Medio Ambiente y la Sección Marítima del Servicio de Aduanas de la colonia británica. Nicolás Fernández condena lo que está ocurriendo, y recuerda que lleva produciéndose años porque Gibraltar considera que dichas aguas son de soberanía británica, algo que no reconoce España.Aunque el dirigente de la patronal pesquera agradece la protesta formulada por el Ministerio de Asuntos Exteriores a Reino Unido por estos hechos, considera que este conflicto debería haber sido resuelto «hace muchos años. Estas llamadas de atención por parte del Gobierno son necesarias pero este problema no es nuevo. No vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar. O se sientan a establecer los límites de las aguas en las que pueden faenar los barcos nacionales o toman cartas en el asunto o tendrán que desplegar a las Fuerzas de Seguridad y al Ejército para que los pescadores puedan faenar», dijo.En ese sentido, Fernández anunció que hoy, viernes, mantendrá una reunión con el alcalde de La Línea de la Concepción, Juan Franco, un encuentro sobre el que no han querido adelantar acontecimientos ni el orden del día a tratar.Cabe recordar que desde este sector se exigió la semana pasada a los Gobiernos de España y del Peñón que se sentaran a establecer los límites de las aguas en las que pueden faenar los barcos nacionales, ante los repetidos incidentes que se están produciendo en esa zona. «Nosotros no vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar», manifestaba Fernández entonces, advirtiendo que «o se sientan y toman cartas en el asunto, o tendrán que poner fuerzas de seguridad y al Ejército para que los pescadores puedan pescar».'),
#  ('articleSection', 'andalucia'),
#  ('@type', 'Person'),
#  ('@context', 'https://schema.org'),
#  ('@type', 'NewsMediaOrganization'),
#  ('@type', 'ImageObject'),
#  ('height', 192),
#  ('url',
#   'https://s2.abcstatics.com/comun/2018/img/iconos-metas/favicon-192x192.png'),
#  ('width', 192),
#  ('@type', 'ImageObject'),
#  ('height', '840'),
#  ('url',
#   'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg'),
#  ('width', '1200'),
#  ('@type', ('CreativeWork', 'Product')),
#  ('name', 'ABC de Sevilla'),
#  ('productID', 'sevilla.abc.es:premium'),
#  ('@id',
#   'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html'),
#  ('@type', 'WebPage'),
#  ('@id', 'https://sevilla.abc.es/#publisher'),
#  ('@type', 'Organization'),
#  ('@type', 'ImageObject'),
#  ('height', 60),
#  ('url', 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png'),
#  ('width', 444),
#  ('@type', 'SpeakableSpecification'),
#  ('xpath',
#   ('/html/head/title', "/html/head/meta[@name='description']/@content"))]
