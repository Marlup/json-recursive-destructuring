# %%
import json
import random
import string
import pprint

# %%
def dir_recursive_json_destructure(data: dict, 
                                   n_nestings: int=0,
                                   on_key_trail: bool=True,
                                   sep: str="-"
                                  ):
    if on_key_trail:
        trailed_keys = []
    keys_with_its_values = []
    only_keys = []
    nesting_found = False
    for key, value in data.items():
        # Only for nested dict-objects
        if isinstance(value, dict):
            if not nesting_found:
                n_nestings += 1
                nesting_found = True
            returned_only_keys, returned_keys_with_its_values, returned_trailed_keys, returned_n_nestings = dir_recursive_json_destructure(value,
                                                                                                                                           n_nestings)
            only_keys.append(key)
            keys_with_its_values.extend(returned_keys_with_its_values)
            if on_key_trail:
                temp = []
                for subkey in returned_trailed_keys:
                    if not isinstance(subkey, tuple):
                        temp.append(f"{key}{sep}{subkey}")
                    else:
                        sub1, sub2 = subkey
                        temp.append(f"{key}{sep}{sub1}{sep}{sub2}")
                trailed_keys.extend(tuple(temp))
            keys_with_its_values.append((key, tuple(returned_only_keys)))
        # Only for last dict-objects
        else:
            only_keys.append(key)
            keys_with_its_values.append((key, str(value)))
    if on_key_trail:
        return only_keys, keys_with_its_values, trailed_keys, n_nestings
    else:
        return only_keys, keys_with_its_values, returned_n_nestings

# %%
def indir_recursive_json_destructure(data: dict, 
                                     on_key_trail: bool=True,
                                     sep: str="-"
                                    ):
    if on_key_trail:
        trailed_keys = []
    only_keys = []
    only_pairs = []
    keys_with_its_values = []
    ret_only_keys = []
    ret_keys_with_its_values = []
    ret_only_pairs = []
    k_iterators = []
    v_iterators = []
    
    keep_search = True
    saved = False
    next_node = True
    
    current_value = data.copy()
    # Iterators
    k_iterators = []
    v_iterators = []
    # Make iterators from level i-th keys
    k_iterator = iter(current_value.keys())
    v_iterator = iter(current_value.values())
    k_aligned = iter(current_value.keys())
    # Treat next level
    k_iterators.append(k_iterator)
    v_iterators.append(v_iterator)
    # Level counters
    max_level = 0
    curr_level = 1
    next_index = 0
    steps = 0

    while keep_search:
        # Try next key
        try: 
            if next_node:
                # Can go to StopIteration-1
                current_node = next(k_iterator)
                next_node = False
            # Can go to StopIteration-2
            current_value = next(v_iterator)
            # Won't fail. Previous next attempt to v_iterator will throw StopIteration first
            # because its length-aligned with k_iterator
            stored_key = next(k_aligned)
        except StopIteration as e:
            # If there's no more values from current node, we have to select the next node
            if not next_node:
                next_node = True
            # If there's no more nodes from current iterator, we have to select the previous iterator
            else:
                next_index = k_iterators.index(k_iterator)
                if next_index == 0:
                    keep_search = False
                    break
                if next_index >= 0:
                    k_iterator = k_iterators[next_index - 1]
                    v_iterator = v_iterators[next_index - 1]
                if curr_level > 1:
                    curr_level -= 1
        if isinstance(current_value, dict) and current_value:
            # Make iterators from level i-th keys
            k_iterator = iter(current_value.keys())
            v_iterator = iter(current_value.values())
            k_aligned = iter(current_value.keys())
            # Treat next level
            k_iterators.append(k_iterator)
            v_iterators.append(v_iterator)
            # Add up for new level
            curr_level += 1
        else:
            if curr_level > max_level:
                max_level = curr_level
        if not next_node:
            # Store data
            ret_only_keys.append(stored_key)
            if isinstance(current_value, (list, set)) and current_value:
                ret_keys_with_its_values.append((stored_key, tuple(current_value)))
            elif not isinstance(current_value, dict):
                ret_keys_with_its_values.append((stored_key, current_value))
                only_pairs.append((stored_key, current_value))
            if saved:
                saved = False
        else:
            if not saved:
                only_keys.extend(ret_only_keys)
                trailed_keys.append(f"{sep}".join(ret_only_keys))
                keys_with_its_values.extend(ret_keys_with_its_values)
                only_pairs.extend(ret_only_pairs)
                ret_only_keys = []
                ret_keys_with_its_values = []
                ret_only_pairs = []
                saved = True
        steps += 1
    return only_keys, keys_with_its_values, trailed_keys, only_pairs, max_level, steps

# %%
def generate_random_data(levels):
    if levels == 0:
        return random.randint(1, 100)
    
    data = {}
    num_keys = random.randint(2, 5)
    for _ in range(num_keys):
        key = ''.join(random.choices(string.ascii_letters, k=5))
        value = generate_random_data(levels - 1)
        data[key] = value
    return data

nested_levels = random.randint(3, 5)
nested_data = generate_random_data(nested_levels)

with open('random_data.json', 'w') as json_file:
    json.dump(nested_data, json_file, indent=4)

print("Random data has been generated and saved to 'random_data.json'.")
# Out:
# Random data has been generated and saved to 'random_data.json'.

# %%
pprint.pprint(nested_data)
# Out:
# {'DcOrk': {'RWAXq': {'CzgwM': {'RrRBn': {'NqJhe': 70, 'hQrUa': 62, 'nbVuJ': 94},
#                                'UECpx': {'OognA': 84, 'svhDa': 23},
#                                'WiWci': {'DxIYq': 92,
#                                          'EFeZT': 45,
#                                          'KEzbS': 8,
#                                          'OIfts': 61,
#                                          'iywVz': 94},
#                                'hqwOJ': {'QUxSm': 52, 'fiRer': 69, 'ohrUo': 48},
#                                'nKHTL': {'Edcam': 55, 'HbxZs': 58}},
#                      'pLraE': {'UkdYr': {'OXLOx': 21,
#                                          'OrXxD': 35,
#                                          'bwRbc': 40,
#                                          'jThwI': 93},
#                                'oRJmz': {'GHwnF': 93,
#                                          'GuKjy': 88,
#                                          'IGGdZ': 99,
#                                          'QikXn': 84,
#                                          'lprfl': 47}},
#                      'yBaNf': {'HHuJQ': {'DeqfE': 81, 'YTjVR': 24},
#                                'JwLWU': {'GAsHR': 33,
#                                          'eNnZN': 41,
#                                          'giYHp': 77,
#                                          'wsBUF': 4},
#                                'SttHc': {'aEpFj': 82, 'ePduB': 70, 'zUovv': 22},
#                                'TmXFJ': {'FpHAL': 45, 'ezgJm': 71, 'naroL': 83},
#                                'uQguN': {'AIORy': 60,
#                                          'BgHNa': 30,
#                                          'crIMT': 17,
#                                          'wEFfG': 76,
#                                          'yvAbo': 3}}},
#            'jnxkA': {'AaVws': {'GGvEL': {'COlmY': 15,
#                                          'IxYVX': 34,
#                                          'OwDpc': 95,
#                                          'Wyqti': 87,
#                                          'yNFyB': 67},
#                                'QPvAT': {'FdLHK': 34, 'JDlUw': 18, 'stnsZ': 71},
#                                'yAqPC': {'cqPjc': 23, 'gwZCi': 8, 'nLCrH': 11}},
#                      'ecAgN': {'BHtSZ': {'JrvWn': 4, 'LRVYm': 71, 'jbybr': 59},
#                                'gMfZg': {'KZhRs': 49,
#                                          'VpLPC': 4,
#                                          'lYbYt': 91,
#                                          'pnaop': 56},
#                                'inwrT': {'Gqtdo': 26, 'IXHRs': 23, 'YHwPK': 70},
#                                'wmjAe': {'armLb': 36,
#                                          'eriBS': 2,
#                                          'kSbcB': 50}}}},
#  'TdfTX': {'Vjgtx': {'MwMDN': {'dhfNw': {'QvpLX': 12, 'lnSwQ': 99},
#                                'lGAWd': {'Gxkcp': 84,
#                                          'LwemF': 77,
#                                          'gbbzP': 6,
#                                          'izIgQ': 21,
#                                          'nYTvY': 39},
#                                'nUIsB': {'TRyUx': 100,
#                                          'gKRrt': 67,
#                                          'jwPxp': 31,
#                                          'pLQIk': 54,
#                                          'pLjzX': 58}},
#                      'VCDUQ': {'QDhYx': {'IorFO': 99, 'LUBXA': 74, 'jqrGH': 45},
#                                'QeUgz': {'CNKdy': 11, 'GcVvj': 12, 'aaKdd': 73},
#                                'uaXXO': {'FtFXz': 29,
#                                          'XSEhm': 72,
#                                          'hzxim': 98}}},
#            'Zarme': {'FPtxZ': {'OZguI': {'MgHTA': 26, 'ckBWp': 68, 'zTYKz': 78},
#                                'OeRAw': {'XWcPr': 38, 'adlsK': 50},
#                                'Sujhm': {'BEmho': 28,
#                                          'EhdHE': 84,
#                                          'ezrYg': 40,
#                                          'ltlxt': 85},
#                                'lEvkM': {'ZcKPh': 43, 'kBKBu': 42},
#                                'pdoMy': {'HmktT': 13,
#                                          'NceBV': 8,
#                                          'noDcS': 81,
#                                          'pODVL': 18}},
#                      'NJYDN': {'FxVvW': {'KTMWg': 16,
#                                          'dKfyD': 75,
#                                          'hNrpJ': 53,
#                                          'nhwBR': 44,
#                                          'wjckn': 71},
#                                'MUokH': {'BMajv': 49,
#                                          'lCyai': 55,
#                                          'qiCmy': 76,
#                                          'rRKGH': 25,
#                                          'racTR': 30},
#                                'RFbUq': {'IYsVD': 93,
#                                          'LPxcD': 20,
#                                          'LcLLG': 59,
#                                          'WfxCS': 64,
#                                          'yLPIa': 31},
#                                'Swetk': {'LCSXR': 16,
#                                          'RkMbt': 53,
#                                          'WYSrW': 30,
#                                          'xJREC': 88}},
#                      'QNBQM': {'geYwW': {'CScEd': 81,
#                                          'TtQab': 83,
#                                          'kgreM': 83,
#                                          'mYkbB': 4},
#                                'zfCBQ': {'FUnRm': 3,
#                                          'PJGJh': 55,
#                                          'bWqLm': 92,
#                                          'hJztp': 25,
#                                          'rBHTB': 56}},
#                      'nMgTU': {'Vxrkl': {'cESVG': 83,
#                                          'iojBB': 15,
#                                          'maPnM': 58,
#                                          'oacCh': 30},
#                                'feKPQ': {'Cimsg': 26, 'rHutI': 30, 'xEQHM': 29},
#                                'oURIA': {'HlIRa': 34,
#                                          'KNKcc': 17,
#                                          'UacmG': 96,
#                                          'eshNZ': 6},
#                                'xjWUa': {'JhTnC': 22,
#                                          'rhXmA': 34,
#                                          'wPThl': 38,
#                                          'zKfGz': 73},
#                                'ybWEG': {'IzkCc': 45,
#                                          'QtXNk': 74,
#                                          'RfjPp': 15,
#                                          'sEfYq': 17,
#                                          'zfzvA': 90}},
#                      'ubJAj': {'Pkyyo': {'Kueks': 98,
#                                          'eNtVv': 51,
#                                          'weDrh': 69,
#                                          'zdDDZ': 73},
#                                'ZNtVU': {'IGGek': 88, 'qWlvN': 94, 'sTeQm': 87},
#                                'dkveo': {'BzaAW': 74, 'SGThj': 41},
#                                'shROo': {'mZdFw': 72, 'uOlgt': 93},
#                                'xouwh': {'HjtoP': 33,
#                                          'KQIFm': 33,
#                                          'bUwGf': 87,
#                                          'cszTJ': 18}}},
#            'eqAeW': {'JKEFl': {'WjYyI': {'FfbJd': 61, 'PlISV': 99, 'UvpHr': 40},
#                                'YpmfF': {'TCWCs': 66, 'ynpCl': 24},
#                                'aYPxq': {'YYTPL': 50, 'byxFp': 77, 'dmWSY': 70},
#                                'cGtzZ': {'deGSG': 56, 'oiAwz': 80},
#                                'pTlKN': {'HIECZ': 25,
#                                          'JgTfR': 71,
#                                          'jpWEE': 2,
#                                          'zIXtK': 50}},
#                      'KJbLf': {'WqPLy': {'TPQvL': 38,
#                                          'amtFB': 33,
#                                          'qgihR': 11,
#                                          'yVFPy': 84},
#                                'lbOpN': {'jjpaQ': 89,
#                                          'pgarV': 45,
#                                          'wFcpD': 22}},
#                      'oCvLu': {'NGKlG': {'IeBVC': 22, 'XwRWG': 59, 'qBLHa': 24},
#                                'PbOKN': {'KHowl': 4, 'QrhMF': 8},
#                                'aalRm': {'GUIVf': 93, 'jdAeb': 69},
#                                'cnrOL': {'QPZbe': 7,
#                                          'fkatm': 85,
#                                          'hdDHY': 82,
#                                          'ppyVO': 80,
#                                          'vcNJh': 4},
#                                'xYyPZ': {'Czcuo': 92,
#                                          'QTSHC': 98,
#                                          'gwYef': 20,
#                                          'tYmlr': 15}},
#                      'vXOGp': {'HVJWA': {'FGkqq': 61,
#                                          'FZzXl': 82,
#                                          'IGOxc': 37,
#                                          'uTEpo': 63},
#                                'QLvgf': {'YvNWB': 27, 'nughk': 19}}},
#            'qlbCC': {'NfpIj': {'NGXGU': {'AKeto': 60, 'TXShq': 72, 'pLMom': 80},
#                                'OsdSy': {'HUvBO': 82, 'iQslV': 61},
#                                'fWcTV': {'DqJoA': 53,
#                                          'IsMno': 98,
#                                          'UmZMk': 86,
#                                          'iucgc': 67,
#                                          'ukfAw': 85},
#                                'hXEaN': {'DxaoR': 53,
#                                          'ZfswF': 69,
#                                          'iPLvI': 81}},
#                      'TtHRY': {'EQiQf': {'JTeke': 43, 'wSeoA': 6, 'ySNKC': 100},
#                                'iEZci': {'JkUTj': 49,
#                                          'LuPKl': 4,
#                                          'VnHVa': 39,
#                                          'bbLVf': 70,
#                                          'hJDXW': 81},
#                                'ltZTa': {'bwmjt': 35,
#                                          'mTdBy': 25,
#                                          'rGwWl': 34,
#                                          'ruSZq': 61,
#                                          'xseOp': 75},
#                                'mvgBK': {'KuGVT': 60,
#                                          'OXGHl': 66,
#                                          'hSTCO': 67,
#                                          'vYjIQ': 24},
#                                'xrzzy': {'Ilbcl': 21,
#                                          'hxFLp': 99,
#                                          'wvRMS': 75}},
#                      'hIToF': {'JQgPL': {'aEXxZ': 25,
#                                          'bRunz': 59,
#                                          'eYWsx': 22,
#                                          'lCLub': 24},
#                                'RItXp': {'dNIht': 23, 'kgyND': 91, 'yGzpY': 46},
#                                'nZIdI': {'REoKJ': 42,
#                                          'YfURY': 28,
#                                          'bzQVb': 34,
#                                          'eaBCx': 68,
#                                          'ymLpK': 34},
#                                'qBTXv': {'XWnEF': 8, 'YKptO': 90, 'avOzG': 93},
#                                'vCaUS': {'AKCwS': 38, 'nLnnT': 7}}},
#            'tZnnJ': {'Fjdzn': {'HCDGp': {'GwjMy': 47,
#                                          'LPZvw': 83,
#                                          'SIarZ': 47,
#                                          'oJlBR': 25},
#                                'cHHeN': {'ALaQa': 30,
#                                          'MPkCz': 37,
#                                          'iMlti': 55,
#                                          'mCsmW': 51,
#                                          'mISYa': 78},
#                                'hCheT': {'GpzPX': 2,
#                                          'VoHKC': 52,
#                                          'XGWmb': 17,
#                                          'amBEl': 66,
#                                          'zuafY': 29},
#                                'rpFFF': {'INkkI': 32,
#                                          'RVwai': 29,
#                                          'pGZiX': 86,
#                                          'wQIZU': 92},
#                                'xWNDo': {'HdcVv': 83,
#                                          'UvSEL': 65,
#                                          'gTOIN': 67}},
#                      'JEvOi': {'aUwwr': {'BDvuo': 47,
#                                          'DHEkH': 43,
#                                          'fHOme': 77,
#                                          'iQMCr': 48,
#                                          'opwsW': 26},
#                                'qWCdy': {'Duqww': 14,
#                                          'SnvyH': 61,
#                                          'VHSHh': 100}},
#                      'Lqcpi': {'Qxuzl': {'CKvYf': 20, 'pYmGy': 69},
#                                'ilQik': {'KtvgN': 95, 'iAoSH': 80, 'kTctU': 1},
#                                'jZLfx': {'DNdun': 23,
#                                          'YwEFC': 34,
#                                          'xifkk': 82}},
#                      'cwptF': {'CyoXU': {'EBJae': 52, 'qaLOm': 48},
#                                'EeDga': {'ZqXWG': 89, 'aHFrI': 20},
#                                'fImOK': {'TMTHJ': 95, 'bGbOT': 93},
#                                'hLbZj': {'KJqdU': 60,
#                                          'Krslg': 33,
#                                          'VwRbh': 22,
#                                          'tNyOX': 70},
#                                'pHqWO': {'IlfUj': 89, 'aUKDl': 43}},
#                      'qfTmB': {'FQyNH': {'PeQLV': 22, 'bGYyB': 88},
#                                'NcYIq': {'CcwUo': 52,
#                                          'EaKyz': 79,
#                                          'LPZvm': 51,
#                                          'eZABM': 65,
#                                          'pqdJF': 69},
#                                'TIycR': {'QeuOC': 19,
#                                          'awOPu': 69,
#                                          'fnqfJ': 66,
#                                          'vcijV': 72,
#                                          'ybJBN': 52},
#                                'wkKwQ': {'IpNSM': 37, 'sBiwr': 21},
#                                'xwImk': {'DxwIR': 18,
#                                          'EdRHf': 48,
#                                          'bwFhC': 9,
#                                          'oSzQT': 76}}}},
#  'WpNtW': {'iedbn': {'KlZbG': {'FsarQ': {'GLLII': 22, 'LhgVT': 2, 'jNfsR': 72},
#                                'WgtpS': {'Cbbiv': 17, 'MSpbi': 25},
#                                'jKhAl': {'CBfhG': 10,
#                                          'DgpxM': 22,
#                                          'FmTbu': 48,
#                                          'TANjE': 12,
#                                          'mYWcP': 78},
#                                'oYlAr': {'WKYLj': 75, 'dKaOT': 28},
#                                'pGdZb': {'QfXNw': 37,
#                                          'Qwijk': 25,
#                                          'UldQd': 48,
#                                          'ahTFU': 49,
#                                          'eEGQI': 38}},
#                      'Kylpc': {'dXWIU': {'DVRgq': 50,
#                                          'TYrzR': 4,
#                                          'jReyo': 63,
#                                          'mabVO': 20,
#                                          'yeUhp': 84},
#                                'xeluQ': {'HpNuj': 7,
#                                          'OVBCZ': 45,
#                                          'ZVRNn': 11,
#                                          'pOPNV': 55}},
#                      'XZrTA': {'FuBbw': {'Mcswy': 22,
#                                          'PaWQQ': 45,
#                                          'hykJL': 96,
#                                          'vdSgk': 27},
#                                'HqiTV': {'HNfse': 69,
#                                          'OJKuI': 89,
#                                          'cIJXZ': 82,
#                                          'vaLIH': 45},
#                                'bcGtJ': {'GKIiF': 99,
#                                          'INglt': 10,
#                                          'oLveR': 10,
#                                          'uxJFe': 94},
#                                'sqFXn': {'iSMaH': 69, 'mOvye': 46}},
#                      'zTTcn': {'RItxn': {'BKfOH': 48,
#                                          'DvcVg': 39,
#                                          'EtWrp': 7,
#                                          'hRmbp': 15,
#                                          'urOmr': 2},
#                                'yocTo': {'IgpMx': 9,
#                                          'PAzGP': 48,
#                                          'WIYkE': 17}}},
#            'xyVtd': {'AMWgR': {'DHSrC': {'AsQpz': 17,
#                                          'XTWXF': 35,
#                                          'kKBpH': 23,
#                                          'lvhvv': 7,
#                                          'tGoMd': 95},
#                                'UzHWv': {'GwwWM': 22,
#                                          'jzaMz': 21,
#                                          'vHbMH': 78,
#                                          'yOtiH': 61},
#                                'fKqkq': {'DFInP': 36,
#                                          'JPoRo': 43,
#                                          'LdzJJ': 100,
#                                          'OTpDA': 32,
#                                          'lveUr': 53}},
#                      'GVtEX': {'EXkzM': {'NfZZM': 49,
#                                          'PPPVm': 55,
#                                          'YjdlT': 67,
#                                          'jpQzs': 23,
#                                          'yIlrY': 62},
#                                'xlbxk': {'MgyMW': 77,
#                                          'QlxDh': 67,
#                                          'ZVnaU': 94,
#                                          'agDbJ': 94}},
#                      'kByvr': {'AoQaf': {'onIZF': 97, 'wOqND': 79},
#                                'XnAqh': {'GsluY': 62,
#                                          'VfrfJ': 33,
#                                          'ZYKEr': 63,
#                                          'pcgDe': 40}},
#                      'vsfiQ': {'FMfPv': {'OTeUC': 37, 'ymzNV': 15},
#                                'dvawk': {'Dvujg': 7,
#                                          'QxZtW': 83,
#                                          'fZbIj': 11,
#                                          'hIXRT': 18,
#                                          'tFjsp': 52},
#                                'sexGr': {'rXiQH': 65, 'xZReD': 39},
#                                'vUBDA': {'TOOhh': 23, 'UfmWJ': 25, 'dzZCV': 53},
#                                'wpvVC': {'BNQAX': 12,
#                                          'OHJaM': 18,
#                                          'UUOOo': 95,
#                                          'hmXtI': 96,
#                                          'pZPCB': 81}}}},
#  'aINAp': {'DuUZO': {'QYKRi': {'RuKuM': {'WDenx': 16,
#                                          'XIVAD': 57,
#                                          'gKJqR': 65,
#                                          'wUQMB': 44},
#                                'SlOnK': {'DVkHb': 38,
#                                          'GGGwD': 85,
#                                          'YBRxd': 35,
#                                          'bUZUW': 2,
#                                          'lYtpx': 62},
#                                'XPwlc': {'ECYiU': 62,
#                                          'GkVFU': 96,
#                                          'xhLHm': 58,
#                                          'xwWlR': 68},
#                                'XTLSB': {'OndhZ': 94,
#                                          'QeJBw': 69,
#                                          'UOhod': 18,
#                                          'WtyNY': 97,
#                                          'iAjyf': 50},
#                                'jElMa': {'bewvI': 85, 'wvlOT': 26}},
#                      'fArXV': {'FCqDd': {'CwXht': 77,
#                                          'DQIwI': 80,
#                                          'GNnfr': 100,
#                                          'UQziw': 6,
#                                          'yvTWI': 38},
#                                'OcsgB': {'VBQxY': 22, 'pSaZq': 20, 'wgbgq': 97},
#                                'nwlsT': {'eSauk': 71, 'jdGsh': 93},
#                                'uaCOi': {'PmrVz': 33,
#                                          'TjruC': 80,
#                                          'lZrGe': 16,
#                                          'semBq': 83}},
#                      'uslny': {'EzcOM': {'Ewytw': 18,
#                                          'JQPVt': 61,
#                                          'Tnxuv': 5,
#                                          'kKboI': 27,
#                                          'uwRij': 79},
#                                'YNQsc': {'AXmPi': 41,
#                                          'SBpfM': 71,
#                                          'SaNpD': 5,
#                                          'aEcBz': 30}},
#                      'waZUg': {'cDyDI': {'SuLAi': 72, 'gzAGE': 7, 'tOmHt': 80},
#                                'cLWzm': {'IDxDx': 49, 'KSVoM': 59},
#                                'fleKl': {'Ncidv': 34, 'pvqhq': 18},
#                                'ldeEI': {'OyFfN': 45,
#                                          'eyJvJ': 53,
#                                          'fkKQB': 5,
#                                          'ycqHd': 71}}},
#            'wPtiL': {'VcfnR': {'JTuUZ': {'OsuXV': 52, 'RCcYz': 30},
#                                'PiMdr': {'KcRSd': 2, 'NJUmi': 66, 'NbLhS': 21},
#                                'bHoYz': {'CHAdr': 10,
#                                          'VuKDz': 30,
#                                          'dkrMp': 38,
#                                          'gIfaQ': 9,
#                                          'mdQAg': 75},
#                                'doqlR': {'QxMam': 21,
#                                          'drWqe': 56,
#                                          'tTKGg': 35,
#                                          'zEyYa': 22},
#                                'tKfAl': {'FvYpq': 94,
#                                          'OeaFl': 63,
#                                          'ZVPRo': 64,
#                                          'kXRbd': 96}},
#                      'lleGZ': {'JjyGk': {'FqfvN': 8,
#                                          'GRQLd': 67,
#                                          'MBayy': 16,
#                                          'STegz': 1,
#                                          'WBBza': 86},
#                                'ZlTbF': {'YaxCu': 97,
#                                          'hxvuQ': 51,
#                                          'nFJsW': 3,
#                                          'qMUlN': 9,
#                                          'yjWzj': 61}}}}}

# %%
json_test1 = {
    'x': {"a": 1, 
          "b": {"ba": 1.2, 
                "bb": 2.2, 
                "bc": 2.3, 
                "bd": 2.4}, 
          "c": 2},
    'y': 3,
    'z': {"c": 4, 
          "d": 5},
    't': {"e": {"f": 6, 
                "g": 7, 
                "h": 8}, 
          "i": [9, 10, 11, 12]}
}

# %%
pprint.pprint(json_test1)
# Out:
# {'t': {'e': {'f': 6, 'g': 7, 'h': 8}, 'i': [9, 10, 11, 12]},
#  'x': {'a': 1, 'b': {'ba': 1.2, 'bb': 2.2, 'bc': 2.3, 'bd': 2.4}, 'c': 2},
#  'y': 3,
#  'z': {'c': 4, 'd': 5}}

# %%
article_json_test2 = {
    '@context': 'https://schema.org',
 '@type': 'NewsArticle',
 'articleBody': 'Nuevo incidente con una embarcación pesquera española en las '
                'aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC '
                'el gerente de la Organización de Productores Pesqueros '
                'Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de '
                'otro pesquero con base en La Línea de la Concepción (Cádiz) '
                'que acudió a este caladero para capturar melva «y cuando '
                'llegó ya lo estaban esperando los de Medio Ambiente de '
                'Gibraltar. Es más de lo mismo. Ha sido coaccionado y '
                'hostigado por intentar faenar donde siempre ».Es el segundo '
                'hostigamiento de las autoridades del Peñón a pesqueros '
                'andaluces. El pasado 21 de agosto, la Policía gibraltareña '
                'retuvo a un pesquero español y acusó a su patrón de graves '
                'delitos supuestamente cometidos en aguas que España reclama '
                'como propias según establece el Tratado de Utrecht. El '
                'pesquero pudo seguir su curso tras la denuncia '
                '.ReincidenciaEl nuevo incidente, apenas nueve días después, '
                'ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer '
                'poco después de las nueve de la mañana. El patrón, un español '
                'de 33 años, ha sido denunciado por agentes de la Sección '
                'Marítima de la Policía Real de Gibraltar asistidos por el '
                'Departamento de Medio Ambiente y la Sección Marítima del '
                'Servicio de Aduanas de la colonia británica. Nicolás '
                'Fernández condena lo que está ocurriendo, y recuerda que '
                'lleva produciéndose años porque Gibraltar considera que '
                'dichas aguas son de soberanía británica, algo que no reconoce '
                'España.Aunque el dirigente de la patronal pesquera agradece '
                'la protesta formulada por el Ministerio de Asuntos Exteriores '
                'a Reino Unido por estos hechos, considera que este conflicto '
                'debería haber sido resuelto «hace muchos años. Estas llamadas '
                'de atención por parte del Gobierno son necesarias pero este '
                'problema no es nuevo. No vamos a dejar de pelear, vamos a '
                'seguir poniendo de manifiesto que es un abuso de las '
                'autoridades de Gibraltar. O se sientan a establecer los '
                'límites de las aguas en las que pueden faenar los barcos '
                'nacionales o toman cartas en el asunto o tendrán que '
                'desplegar a las Fuerzas de Seguridad y al Ejército para que '
                'los pescadores puedan faenar», dijo.En ese sentido, Fernández '
                'anunció que hoy, viernes, mantendrá una reunión con el '
                'alcalde de La Línea de la Concepción, Juan Franco, un '
                'encuentro sobre el que no han querido adelantar '
                'acontecimientos ni el orden del día a tratar.Cabe recordar '
                'que desde este sector se exigió la semana pasada a los '
                'Gobiernos de España y del Peñón que se sentaran a establecer '
                'los límites de las aguas en las que pueden faenar los barcos '
                'nacionales, ante los repetidos incidentes que se están '
                'produciendo en esa zona. «Nosotros no vamos a dejar de '
                'pelear, vamos a seguir poniendo de manifiesto que es un abuso '
                'de las autoridades de Gibraltar», manifestaba Fernández '
                'entonces, advirtiendo que «o se sientan y toman cartas en el '
                'asunto, o tendrán que poner fuerzas de seguridad y al '
                'Ejército para que los pescadores puedan pescar».',
 'articleSection': 'andalucia',
 'author': [{'@type': 'Person',
             'memberOf': {'@context': 'https://schema.org',
                          '@type': 'NewsMediaOrganization',
                          'logo': {'@type': 'ImageObject',
                                   'height': 192,
                                   'url': 'https://s2.abcstatics.com/comun/2018/img/iconos-metas/favicon-192x192.png',
                                   'width': 192},
                          'name': 'ABC de Sevilla',
                          'url': 'https://sevilla.abc.es'},
             'name': 'Soraya Fernández',
             'url': 'https://sevilla.abc.es/autor/soraya-fernandez-6267/'}],
 'dateModified': '2023-09-01T04:23:30+02:00',
 'datePublished': '2023-09-01T04:23:30+02:00',
 'dateline': 'Spain',
 'description': '«Ha sido coaccionado y hostigado por intentar faenar donde '
                'siempre», dicen los pescadores',
 'headline': 'Gibraltar vuelve a impedir faenar a otro pesquero español',
 'image': {'@type': 'ImageObject',
           'height': '840',
           'url': 'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg',
           'width': '1200'},
 'inLanguage': 'es',
 'isAccessibleForFree': 'True',
 'isPartOf': {'@type': ['CreativeWork', 'Product'],
              'name': 'ABC de Sevilla',
              'productID': 'sevilla.abc.es:premium'},
 'keywords': ['Informaciones', 'Cádiz (Provincia)', 'ABC de Sevilla'],
 'mainEntityOfPage': {'@id': 'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html',
                      '@type': 'WebPage'},
 'publisher': {'@id': 'https://sevilla.abc.es/#publisher',
               '@type': 'Organization',
               'logo': {'@type': 'ImageObject',
                        'height': 60,
                        'url': 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png',
                        'width': 444},
               'name': 'ABC Andalucía',
               'sameAs': ['https://twitter.com/abcdesevilla/',
                          'https://www.facebook.com/abcdesevilla/',
                          'https://www.instagram.com/abcdesevilla/'],
               'url': 'https://sevilla.abc.es'},
 'speakable': {'@type': 'SpeakableSpecification',
               'xpath': ['/html/head/title',
                         "/html/head/meta[@name='description']/@content"]},
 'wordCount': '483'}

# %%
pprint.pprint(article_json_test2)
# Out:
# {'@context': 'https://schema.org',
#  '@type': 'NewsArticle',
#  'articleBody': 'Nuevo incidente con una embarcación pesquera española en las '
#                 'aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC '
#                 'el gerente de la Organización de Productores Pesqueros '
#                 'Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de '
#                 'otro pesquero con base en La Línea de la Concepción (Cádiz) '
#                 'que acudió a este caladero para capturar melva «y cuando '
#                 'llegó ya lo estaban esperando los de Medio Ambiente de '
#                 'Gibraltar. Es más de lo mismo. Ha sido coaccionado y '
#                 'hostigado por intentar faenar donde siempre ».Es el segundo '
#                 'hostigamiento de las autoridades del Peñón a pesqueros '
#                 'andaluces. El pasado 21 de agosto, la Policía gibraltareña '
#                 'retuvo a un pesquero español y acusó a su patrón de graves '
#                 'delitos supuestamente cometidos en aguas que España reclama '
#                 'como propias según establece el Tratado de Utrecht. El '
#                 'pesquero pudo seguir su curso tras la denuncia '
#                 '.ReincidenciaEl nuevo incidente, apenas nueve días después, '
#                 'ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer '
#                 'poco después de las nueve de la mañana. El patrón, un español '
#                 'de 33 años, ha sido denunciado por agentes de la Sección '
#                 'Marítima de la Policía Real de Gibraltar asistidos por el '
#                 'Departamento de Medio Ambiente y la Sección Marítima del '
#                 'Servicio de Aduanas de la colonia británica. Nicolás '
#                 'Fernández condena lo que está ocurriendo, y recuerda que '
#                 'lleva produciéndose años porque Gibraltar considera que '
#                 'dichas aguas son de soberanía británica, algo que no reconoce '
#                 'España.Aunque el dirigente de la patronal pesquera agradece '
#                 'la protesta formulada por el Ministerio de Asuntos Exteriores '
#                 'a Reino Unido por estos hechos, considera que este conflicto '
#                 'debería haber sido resuelto «hace muchos años. Estas llamadas '
#                 'de atención por parte del Gobierno son necesarias pero este '
#                 'problema no es nuevo. No vamos a dejar de pelear, vamos a '
#                 'seguir poniendo de manifiesto que es un abuso de las '
#                 'autoridades de Gibraltar. O se sientan a establecer los '
#                 'límites de las aguas en las que pueden faenar los barcos '
#                 'nacionales o toman cartas en el asunto o tendrán que '
#                 'desplegar a las Fuerzas de Seguridad y al Ejército para que '
#                 'los pescadores puedan faenar», dijo.En ese sentido, Fernández '
#                 'anunció que hoy, viernes, mantendrá una reunión con el '
#                 'alcalde de La Línea de la Concepción, Juan Franco, un '
#                 'encuentro sobre el que no han querido adelantar '
#                 'acontecimientos ni el orden del día a tratar.Cabe recordar '
#                 'que desde este sector se exigió la semana pasada a los '
#                 'Gobiernos de España y del Peñón que se sentaran a establecer '
#                 'los límites de las aguas en las que pueden faenar los barcos '
#                 'nacionales, ante los repetidos incidentes que se están '
#                 'produciendo en esa zona. «Nosotros no vamos a dejar de '
#                 'pelear, vamos a seguir poniendo de manifiesto que es un abuso '
#                 'de las autoridades de Gibraltar», manifestaba Fernández '
#                 'entonces, advirtiendo que «o se sientan y toman cartas en el '
#                 'asunto, o tendrán que poner fuerzas de seguridad y al '
#                 'Ejército para que los pescadores puedan pescar».',
#  'articleSection': 'andalucia',
#  'author': [{'@type': 'Person',
#              'memberOf': {'@context': 'https://schema.org',
#                           '@type': 'NewsMediaOrganization',
#                           'logo': {'@type': 'ImageObject',
#                                    'height': 192,
#                                    'url': 'https://s2.abcstatics.com/comun/2018/img/iconos-metas/favicon-192x192.png',
#                                    'width': 192},
#                           'name': 'ABC de Sevilla',
#                           'url': 'https://sevilla.abc.es'},
#              'name': 'Soraya Fernández',
#              'url': 'https://sevilla.abc.es/autor/soraya-fernandez-6267/'}],
#  'dateModified': '2023-09-01T04:23:30+02:00',
#  'datePublished': '2023-09-01T04:23:30+02:00',
#  'dateline': 'Spain',
#  'description': '«Ha sido coaccionado y hostigado por intentar faenar donde '
#                 'siempre», dicen los pescadores',
#  'headline': 'Gibraltar vuelve a impedir faenar a otro pesquero español',
#  'image': {'@type': 'ImageObject',
#            'height': '840',
#            'url': 'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg',
#            'width': '1200'},
#  'inLanguage': 'es',
#  'isAccessibleForFree': 'True',
#  'isPartOf': {'@type': ['CreativeWork', 'Product'],
#               'name': 'ABC de Sevilla',
#               'productID': 'sevilla.abc.es:premium'},
#  'keywords': ['Informaciones', 'Cádiz (Provincia)', 'ABC de Sevilla'],
#  'mainEntityOfPage': {'@id': 'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html',
#                       '@type': 'WebPage'},
#  'publisher': {'@id': 'https://sevilla.abc.es/#publisher',
#                '@type': 'Organization',
#                'logo': {'@type': 'ImageObject',
#                         'height': 60,
#                         'url': 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png',
#                         'width': 444},
#                'name': 'ABC Andalucía',
#                'sameAs': ['https://twitter.com/abcdesevilla/',
#                           'https://www.facebook.com/abcdesevilla/',
#                           'https://www.instagram.com/abcdesevilla/'],
#                'url': 'https://sevilla.abc.es'},
#  'speakable': {'@type': 'SpeakableSpecification',
#                'xpath': ['/html/head/title',
#                          "/html/head/meta[@name='description']/@content"]},
#  'wordCount': '483'}

# %%
only_keys1, keys_with_its_values1, trailed_keys1, returned_n_nestings1 = dir_recursive_json_destructure(article_json_test2)
returned_n_nestings1, len(only_keys1), len(keys_with_its_values1), len(trailed_keys1), len(keys_with_its_values1)
# Out:
# (1, 19, 40, 0, 40)

# %%
only_keys1
# Out:
# ['@context',
#  '@type',
#  'articleBody',
#  'articleSection',
#  'author',
#  'dateModified',
#  'datePublished',
#  'dateline',
#  'description',
#  'headline',
#  'image',
#  'inLanguage',
#  'isAccessibleForFree',
#  'isPartOf',
#  'keywords',
#  'mainEntityOfPage',
#  'publisher',
#  'speakable',
#  'wordCount']

# %%
keys_with_its_values1
# Out:
# [('@context', 'https://schema.org'),
#  ('@type', 'NewsArticle'),
#  ('articleBody',
#   'Nuevo incidente con una embarcación pesquera española en las aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC el gerente de la Organización de Productores Pesqueros Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de otro pesquero con base en La Línea de la Concepción (Cádiz) que acudió a este caladero para capturar melva «y cuando llegó ya lo estaban esperando los de Medio Ambiente de Gibraltar. Es más de lo mismo. Ha sido coaccionado y hostigado por intentar faenar donde siempre ».Es el segundo hostigamiento de las autoridades del Peñón a pesqueros andaluces. El pasado 21 de agosto, la Policía gibraltareña retuvo a un pesquero español y acusó a su patrón de graves delitos supuestamente cometidos en aguas que España reclama como propias según establece el Tratado de Utrecht. El pesquero pudo seguir su curso tras la denuncia .ReincidenciaEl nuevo incidente, apenas nueve días después, ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer poco después de las nueve de la mañana. El patrón, un español de 33 años, ha sido denunciado por agentes de la Sección Marítima de la Policía Real de Gibraltar asistidos por el Departamento de Medio Ambiente y la Sección Marítima del Servicio de Aduanas de la colonia británica. Nicolás Fernández condena lo que está ocurriendo, y recuerda que lleva produciéndose años porque Gibraltar considera que dichas aguas son de soberanía británica, algo que no reconoce España.Aunque el dirigente de la patronal pesquera agradece la protesta formulada por el Ministerio de Asuntos Exteriores a Reino Unido por estos hechos, considera que este conflicto debería haber sido resuelto «hace muchos años. Estas llamadas de atención por parte del Gobierno son necesarias pero este problema no es nuevo. No vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar. O se sientan a establecer los límites de las aguas en las que pueden faenar los barcos nacionales o toman cartas en el asunto o tendrán que desplegar a las Fuerzas de Seguridad y al Ejército para que los pescadores puedan faenar», dijo.En ese sentido, Fernández anunció que hoy, viernes, mantendrá una reunión con el alcalde de La Línea de la Concepción, Juan Franco, un encuentro sobre el que no han querido adelantar acontecimientos ni el orden del día a tratar.Cabe recordar que desde este sector se exigió la semana pasada a los Gobiernos de España y del Peñón que se sentaran a establecer los límites de las aguas en las que pueden faenar los barcos nacionales, ante los repetidos incidentes que se están produciendo en esa zona. «Nosotros no vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar», manifestaba Fernández entonces, advirtiendo que «o se sientan y toman cartas en el asunto, o tendrán que poner fuerzas de seguridad y al Ejército para que los pescadores puedan pescar».'),
#  ('articleSection', 'andalucia'),
#  ('author',
#   "[{'@type': 'Person', 'memberOf': {'@context': 'https://schema.org', '@type': 'NewsMediaOrganization', 'logo': {'@type': 'ImageObject', 'height': 192, 'url': 'https://s2.abcstatics.com/comun/2018/img/iconos-metas/favicon-192x192.png', 'width': 192}, 'name': 'ABC de Sevilla', 'url': 'https://sevilla.abc.es'}, 'name': 'Soraya Fernández', 'url': 'https://sevilla.abc.es/autor/soraya-fernandez-6267/'}]"),
#  ('dateModified', '2023-09-01T04:23:30+02:00'),
#  ('datePublished', '2023-09-01T04:23:30+02:00'),
#  ('dateline', 'Spain'),
#  ('description',
#   '«Ha sido coaccionado y hostigado por intentar faenar donde siempre», dicen los pescadores'),
#  ('headline', 'Gibraltar vuelve a impedir faenar a otro pesquero español'),
#  ('@type', 'ImageObject'),
#  ('height', '840'),
#  ('url',
#   'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg'),
#  ('width', '1200'),
#  ('image', ('@type', 'height', 'url', 'width')),
#  ('inLanguage', 'es'),
#  ('isAccessibleForFree', 'True'),
#  ('@type', "['CreativeWork', 'Product']"),
#  ('name', 'ABC de Sevilla'),
#  ('productID', 'sevilla.abc.es:premium'),
#  ('isPartOf', ('@type', 'name', 'productID')),
#  ('keywords', "['Informaciones', 'Cádiz (Provincia)', 'ABC de Sevilla']"),
#  ('@id',
#   'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html'),
#  ('@type', 'WebPage'),
#  ('mainEntityOfPage', ('@id', '@type')),
#  ('@id', 'https://sevilla.abc.es/#publisher'),
#  ('@type', 'Organization'),
#  ('@type', 'ImageObject'),
#  ('height', '60'),
#  ('url', 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png'),
#  ('width', '444'),
#  ('logo', ('@type', 'height', 'url', 'width')),
#  ('name', 'ABC Andalucía'),
#  ('sameAs',
#   "['https://twitter.com/abcdesevilla/', 'https://www.facebook.com/abcdesevilla/', 'https://www.instagram.com/abcdesevilla/']"),
#  ('url', 'https://sevilla.abc.es'),
#  ('publisher', ('@id', '@type', 'logo', 'name', 'sameAs', 'url')),
#  ('@type', 'SpeakableSpecification'),
#  ('xpath',
#   '[\'/html/head/title\', "/html/head/meta[@name=\'description\']/@content"]'),
#  ('speakable', ('@type', 'xpath')),
#  ('wordCount', '483')]

# %%
trailed_keys1
# Out:
# []

# %%
only_keys2, keys_values2, trailed_keys2, only_pairs2, n_nestings2, steps2 = indir_recursive_json_destructure(article_json_test2)
print(n_nestings2, steps2, len(keys_values2), end="\n\n")
# Out:
# 3 86 27

# %%
# %timeit dir_recursive_json_destructure(article_json_test2)
# %timeit indir_recursive_json_destructure(article_json_test2)
# Out:
# 19.9 µs ± 271 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 54.8 µs ± 401 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
only_keys2
# Out:
# ['@context',
#  '@type',
#  'articleBody',
#  'articleSection',
#  'author',
#  'dateModified',
#  'datePublished',
#  'dateline',
#  'description',
#  'headline',
#  'image',
#  '@type',
#  'height',
#  'url',
#  'width',
#  '@type',
#  'name',
#  'productID',
#  '@id',
#  '@type',
#  '@id',
#  '@type',
#  'logo',
#  '@type',
#  'height',
#  'url',
#  'width',
#  '@type',
#  'xpath']

# %%
trailed_keys2
# Out:
# ['@context-@type-articleBody-articleSection-author-dateModified-datePublished-dateline-description-headline-image-@type-height-url-width',
#  '@type-name-productID',
#  '@id-@type',
#  '@id-@type-logo-@type-height-url-width',
#  '@type-xpath']

# %%
only_pairs2
# Out:
# [('@context', 'https://schema.org'),
#  ('@type', 'NewsArticle'),
#  ('articleBody',
#   'Nuevo incidente con una embarcación pesquera española en las aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC el gerente de la Organización de Productores Pesqueros Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de otro pesquero con base en La Línea de la Concepción (Cádiz) que acudió a este caladero para capturar melva «y cuando llegó ya lo estaban esperando los de Medio Ambiente de Gibraltar. Es más de lo mismo. Ha sido coaccionado y hostigado por intentar faenar donde siempre ».Es el segundo hostigamiento de las autoridades del Peñón a pesqueros andaluces. El pasado 21 de agosto, la Policía gibraltareña retuvo a un pesquero español y acusó a su patrón de graves delitos supuestamente cometidos en aguas que España reclama como propias según establece el Tratado de Utrecht. El pesquero pudo seguir su curso tras la denuncia .ReincidenciaEl nuevo incidente, apenas nueve días después, ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer poco después de las nueve de la mañana. El patrón, un español de 33 años, ha sido denunciado por agentes de la Sección Marítima de la Policía Real de Gibraltar asistidos por el Departamento de Medio Ambiente y la Sección Marítima del Servicio de Aduanas de la colonia británica. Nicolás Fernández condena lo que está ocurriendo, y recuerda que lleva produciéndose años porque Gibraltar considera que dichas aguas son de soberanía británica, algo que no reconoce España.Aunque el dirigente de la patronal pesquera agradece la protesta formulada por el Ministerio de Asuntos Exteriores a Reino Unido por estos hechos, considera que este conflicto debería haber sido resuelto «hace muchos años. Estas llamadas de atención por parte del Gobierno son necesarias pero este problema no es nuevo. No vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar. O se sientan a establecer los límites de las aguas en las que pueden faenar los barcos nacionales o toman cartas en el asunto o tendrán que desplegar a las Fuerzas de Seguridad y al Ejército para que los pescadores puedan faenar», dijo.En ese sentido, Fernández anunció que hoy, viernes, mantendrá una reunión con el alcalde de La Línea de la Concepción, Juan Franco, un encuentro sobre el que no han querido adelantar acontecimientos ni el orden del día a tratar.Cabe recordar que desde este sector se exigió la semana pasada a los Gobiernos de España y del Peñón que se sentaran a establecer los límites de las aguas en las que pueden faenar los barcos nacionales, ante los repetidos incidentes que se están produciendo en esa zona. «Nosotros no vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar», manifestaba Fernández entonces, advirtiendo que «o se sientan y toman cartas en el asunto, o tendrán que poner fuerzas de seguridad y al Ejército para que los pescadores puedan pescar».'),
#  ('articleSection', 'andalucia'),
#  ('dateModified', '2023-09-01T04:23:30+02:00'),
#  ('datePublished', '2023-09-01T04:23:30+02:00'),
#  ('dateline', 'Spain'),
#  ('description',
#   '«Ha sido coaccionado y hostigado por intentar faenar donde siempre», dicen los pescadores'),
#  ('headline', 'Gibraltar vuelve a impedir faenar a otro pesquero español'),
#  ('@type', 'ImageObject'),
#  ('height', '840'),
#  ('url',
#   'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg'),
#  ('width', '1200'),
#  ('name', 'ABC de Sevilla'),
#  ('productID', 'sevilla.abc.es:premium'),
#  ('@id',
#   'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html'),
#  ('@type', 'WebPage'),
#  ('@id', 'https://sevilla.abc.es/#publisher'),
#  ('@type', 'Organization'),
#  ('@type', 'ImageObject'),
#  ('height', 60),
#  ('url', 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png'),
#  ('width', 444),
#  ('@type', 'SpeakableSpecification')]

# %%
keys_with_its_values1
# Out:
# [('@context', 'https://schema.org'),
#  ('@type', 'NewsArticle'),
#  ('articleBody',
#   'Nuevo incidente con una embarcación pesquera española en las aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC el gerente de la Organización de Productores Pesqueros Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de otro pesquero con base en La Línea de la Concepción (Cádiz) que acudió a este caladero para capturar melva «y cuando llegó ya lo estaban esperando los de Medio Ambiente de Gibraltar. Es más de lo mismo. Ha sido coaccionado y hostigado por intentar faenar donde siempre ».Es el segundo hostigamiento de las autoridades del Peñón a pesqueros andaluces. El pasado 21 de agosto, la Policía gibraltareña retuvo a un pesquero español y acusó a su patrón de graves delitos supuestamente cometidos en aguas que España reclama como propias según establece el Tratado de Utrecht. El pesquero pudo seguir su curso tras la denuncia .ReincidenciaEl nuevo incidente, apenas nueve días después, ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer poco después de las nueve de la mañana. El patrón, un español de 33 años, ha sido denunciado por agentes de la Sección Marítima de la Policía Real de Gibraltar asistidos por el Departamento de Medio Ambiente y la Sección Marítima del Servicio de Aduanas de la colonia británica. Nicolás Fernández condena lo que está ocurriendo, y recuerda que lleva produciéndose años porque Gibraltar considera que dichas aguas son de soberanía británica, algo que no reconoce España.Aunque el dirigente de la patronal pesquera agradece la protesta formulada por el Ministerio de Asuntos Exteriores a Reino Unido por estos hechos, considera que este conflicto debería haber sido resuelto «hace muchos años. Estas llamadas de atención por parte del Gobierno son necesarias pero este problema no es nuevo. No vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar. O se sientan a establecer los límites de las aguas en las que pueden faenar los barcos nacionales o toman cartas en el asunto o tendrán que desplegar a las Fuerzas de Seguridad y al Ejército para que los pescadores puedan faenar», dijo.En ese sentido, Fernández anunció que hoy, viernes, mantendrá una reunión con el alcalde de La Línea de la Concepción, Juan Franco, un encuentro sobre el que no han querido adelantar acontecimientos ni el orden del día a tratar.Cabe recordar que desde este sector se exigió la semana pasada a los Gobiernos de España y del Peñón que se sentaran a establecer los límites de las aguas en las que pueden faenar los barcos nacionales, ante los repetidos incidentes que se están produciendo en esa zona. «Nosotros no vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar», manifestaba Fernández entonces, advirtiendo que «o se sientan y toman cartas en el asunto, o tendrán que poner fuerzas de seguridad y al Ejército para que los pescadores puedan pescar».'),
#  ('articleSection', 'andalucia'),
#  ('author',
#   "[{'@type': 'Person', 'memberOf': {'@context': 'https://schema.org', '@type': 'NewsMediaOrganization', 'logo': {'@type': 'ImageObject', 'height': 192, 'url': 'https://s2.abcstatics.com/comun/2018/img/iconos-metas/favicon-192x192.png', 'width': 192}, 'name': 'ABC de Sevilla', 'url': 'https://sevilla.abc.es'}, 'name': 'Soraya Fernández', 'url': 'https://sevilla.abc.es/autor/soraya-fernandez-6267/'}]"),
#  ('dateModified', '2023-09-01T04:23:30+02:00'),
#  ('datePublished', '2023-09-01T04:23:30+02:00'),
#  ('dateline', 'Spain'),
#  ('description',
#   '«Ha sido coaccionado y hostigado por intentar faenar donde siempre», dicen los pescadores'),
#  ('headline', 'Gibraltar vuelve a impedir faenar a otro pesquero español'),
#  ('@type', 'ImageObject'),
#  ('height', '840'),
#  ('url',
#   'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg'),
#  ('width', '1200'),
#  ('image', ('@type', 'height', 'url', 'width')),
#  ('inLanguage', 'es'),
#  ('isAccessibleForFree', 'True'),
#  ('@type', "['CreativeWork', 'Product']"),
#  ('name', 'ABC de Sevilla'),
#  ('productID', 'sevilla.abc.es:premium'),
#  ('isPartOf', ('@type', 'name', 'productID')),
#  ('keywords', "['Informaciones', 'Cádiz (Provincia)', 'ABC de Sevilla']"),
#  ('@id',
#   'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html'),
#  ('@type', 'WebPage'),
#  ('mainEntityOfPage', ('@id', '@type')),
#  ('@id', 'https://sevilla.abc.es/#publisher'),
#  ('@type', 'Organization'),
#  ('@type', 'ImageObject'),
#  ('height', '60'),
#  ('url', 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png'),
#  ('width', '444'),
#  ('logo', ('@type', 'height', 'url', 'width')),
#  ('name', 'ABC Andalucía'),
#  ('sameAs',
#   "['https://twitter.com/abcdesevilla/', 'https://www.facebook.com/abcdesevilla/', 'https://www.instagram.com/abcdesevilla/']"),
#  ('url', 'https://sevilla.abc.es'),
#  ('publisher', ('@id', '@type', 'logo', 'name', 'sameAs', 'url')),
#  ('@type', 'SpeakableSpecification'),
#  ('xpath',
#   '[\'/html/head/title\', "/html/head/meta[@name=\'description\']/@content"]'),
#  ('speakable', ('@type', 'xpath')),
#  ('wordCount', '483')]

# %% [markdown]
# ### Case with no list as value

# %%
article_json_test3 = {
    '@context': 'https://schema.org',
 '@type': 'NewsArticle',
 'articleBody': 'Nuevo incidente con una embarcación pesquera española en las '
                'aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC '
                'el gerente de la Organización de Productores Pesqueros '
                'Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de '
                'otro pesquero con base en La Línea de la Concepción (Cádiz) '
                'que acudió a este caladero para capturar melva «y cuando '
                'llegó ya lo estaban esperando los de Medio Ambiente de '
                'Gibraltar. Es más de lo mismo. Ha sido coaccionado y '
                'hostigado por intentar faenar donde siempre ».Es el segundo '
                'hostigamiento de las autoridades del Peñón a pesqueros '
                'andaluces. El pasado 21 de agosto, la Policía gibraltareña '
                'retuvo a un pesquero español y acusó a su patrón de graves '
                'delitos supuestamente cometidos en aguas que España reclama '
                'como propias según establece el Tratado de Utrecht. El '
                'pesquero pudo seguir su curso tras la denuncia '
                '.ReincidenciaEl nuevo incidente, apenas nueve días después, '
                'ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer '
                'poco después de las nueve de la mañana. El patrón, un español '
                'de 33 años, ha sido denunciado por agentes de la Sección '
                'Marítima de la Policía Real de Gibraltar asistidos por el '
                'Departamento de Medio Ambiente y la Sección Marítima del '
                'Servicio de Aduanas de la colonia británica. Nicolás '
                'Fernández condena lo que está ocurriendo, y recuerda que '
                'lleva produciéndose años porque Gibraltar considera que '
                'dichas aguas son de soberanía británica, algo que no reconoce '
                'España.Aunque el dirigente de la patronal pesquera agradece '
                'la protesta formulada por el Ministerio de Asuntos Exteriores '
                'a Reino Unido por estos hechos, considera que este conflicto '
                'debería haber sido resuelto «hace muchos años. Estas llamadas '
                'de atención por parte del Gobierno son necesarias pero este '
                'problema no es nuevo. No vamos a dejar de pelear, vamos a '
                'seguir poniendo de manifiesto que es un abuso de las '
                'autoridades de Gibraltar. O se sientan a establecer los '
                'límites de las aguas en las que pueden faenar los barcos '
                'nacionales o toman cartas en el asunto o tendrán que '
                'desplegar a las Fuerzas de Seguridad y al Ejército para que '
                'los pescadores puedan faenar», dijo.En ese sentido, Fernández '
                'anunció que hoy, viernes, mantendrá una reunión con el '
                'alcalde de La Línea de la Concepción, Juan Franco, un '
                'encuentro sobre el que no han querido adelantar '
                'acontecimientos ni el orden del día a tratar.Cabe recordar '
                'que desde este sector se exigió la semana pasada a los '
                'Gobiernos de España y del Peñón que se sentaran a establecer '
                'los límites de las aguas en las que pueden faenar los barcos '
                'nacionales, ante los repetidos incidentes que se están '
                'produciendo en esa zona. «Nosotros no vamos a dejar de '
                'pelear, vamos a seguir poniendo de manifiesto que es un abuso '
                'de las autoridades de Gibraltar», manifestaba Fernández '
                'entonces, advirtiendo que «o se sientan y toman cartas en el '
                'asunto, o tendrán que poner fuerzas de seguridad y al '
                'Ejército para que los pescadores puedan pescar».',
 'articleSection': 'andalucia',
 'author': {'@type': 'Person',
             'memberOf': {'@context': 'https://schema.org',
                          '@type': 'NewsMediaOrganization',
                          'logo': {'@type': 'ImageObject',
                                   'height': 192,
                                   'url': 'https://s2.abcstatics.com/comun/2018/img/iconos-metas/favicon-192x192.png',
                                   'width': 192},
                          'name': 'ABC de Sevilla',
                          'url': 'https://sevilla.abc.es'},
             'name': 'Soraya Fernández',
             'url': 'https://sevilla.abc.es/autor/soraya-fernandez-6267/'},
 'dateModified': '2023-09-01T04:23:30+02:00',
 'datePublished': '2023-09-01T04:23:30+02:00',
 'dateline': 'Spain',
 'description': '«Ha sido coaccionado y hostigado por intentar faenar donde '
                'siempre», dicen los pescadores',
 'headline': 'Gibraltar vuelve a impedir faenar a otro pesquero español',
 'image': {'@type': 'ImageObject',
           'height': '840',
           'url': 'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg',
           'width': '1200'},
 'inLanguage': 'es',
 'isAccessibleForFree': 'True',
 'isPartOf': {'@type': ['CreativeWork', 'Product'],
              'name': 'ABC de Sevilla',
              'productID': 'sevilla.abc.es:premium'},
 'keywords': ['Informaciones', 'Cádiz (Provincia)', 'ABC de Sevilla'],
 'mainEntityOfPage': {'@id': 'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html',
                      '@type': 'WebPage'},
 'publisher': {'@id': 'https://sevilla.abc.es/#publisher',
               '@type': 'Organization',
               'logo': {'@type': 'ImageObject',
                        'height': 60,
                        'url': 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png',
                        'width': 444},
               'name': 'ABC Andalucía',
               'sameAs': ['https://twitter.com/abcdesevilla/',
                          'https://www.facebook.com/abcdesevilla/',
                          'https://www.instagram.com/abcdesevilla/'],
               'url': 'https://sevilla.abc.es'},
 'speakable': {'@type': 'SpeakableSpecification',
               'xpath': ['/html/head/title',
                         "/html/head/meta[@name='description']/@content"]},
 'wordCount': '483'}
pprint.pprint(article_json_test3)
# Out:
# {'@context': 'https://schema.org',
#  '@type': 'NewsArticle',
#  'articleBody': 'Nuevo incidente con una embarcación pesquera española en las '
#                 'aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC '
#                 'el gerente de la Organización de Productores Pesqueros '
#                 'Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de '
#                 'otro pesquero con base en La Línea de la Concepción (Cádiz) '
#                 'que acudió a este caladero para capturar melva «y cuando '
#                 'llegó ya lo estaban esperando los de Medio Ambiente de '
#                 'Gibraltar. Es más de lo mismo. Ha sido coaccionado y '
#                 'hostigado por intentar faenar donde siempre ».Es el segundo '
#                 'hostigamiento de las autoridades del Peñón a pesqueros '
#                 'andaluces. El pasado 21 de agosto, la Policía gibraltareña '
#                 'retuvo a un pesquero español y acusó a su patrón de graves '
#                 'delitos supuestamente cometidos en aguas que España reclama '
#                 'como propias según establece el Tratado de Utrecht. El '
#                 'pesquero pudo seguir su curso tras la denuncia '
#                 '.ReincidenciaEl nuevo incidente, apenas nueve días después, '
#                 'ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer '
#                 'poco después de las nueve de la mañana. El patrón, un español '
#                 'de 33 años, ha sido denunciado por agentes de la Sección '
#                 'Marítima de la Policía Real de Gibraltar asistidos por el '
#                 'Departamento de Medio Ambiente y la Sección Marítima del '
#                 'Servicio de Aduanas de la colonia británica. Nicolás '
#                 'Fernández condena lo que está ocurriendo, y recuerda que '
#                 'lleva produciéndose años porque Gibraltar considera que '
#                 'dichas aguas son de soberanía británica, algo que no reconoce '
#                 'España.Aunque el dirigente de la patronal pesquera agradece '
#                 'la protesta formulada por el Ministerio de Asuntos Exteriores '
#                 'a Reino Unido por estos hechos, considera que este conflicto '
#                 'debería haber sido resuelto «hace muchos años. Estas llamadas '
#                 'de atención por parte del Gobierno son necesarias pero este '
#                 'problema no es nuevo. No vamos a dejar de pelear, vamos a '
#                 'seguir poniendo de manifiesto que es un abuso de las '
#                 'autoridades de Gibraltar. O se sientan a establecer los '
#                 'límites de las aguas en las que pueden faenar los barcos '
#                 'nacionales o toman cartas en el asunto o tendrán que '
#                 'desplegar a las Fuerzas de Seguridad y al Ejército para que '
#                 'los pescadores puedan faenar», dijo.En ese sentido, Fernández '
#                 'anunció que hoy, viernes, mantendrá una reunión con el '
#                 'alcalde de La Línea de la Concepción, Juan Franco, un '
#                 'encuentro sobre el que no han querido adelantar '
#                 'acontecimientos ni el orden del día a tratar.Cabe recordar '
#                 'que desde este sector se exigió la semana pasada a los '
#                 'Gobiernos de España y del Peñón que se sentaran a establecer '
#                 'los límites de las aguas en las que pueden faenar los barcos '
#                 'nacionales, ante los repetidos incidentes que se están '
#                 'produciendo en esa zona. «Nosotros no vamos a dejar de '
#                 'pelear, vamos a seguir poniendo de manifiesto que es un abuso '
#                 'de las autoridades de Gibraltar», manifestaba Fernández '
#                 'entonces, advirtiendo que «o se sientan y toman cartas en el '
#                 'asunto, o tendrán que poner fuerzas de seguridad y al '
#                 'Ejército para que los pescadores puedan pescar».',
#  'articleSection': 'andalucia',
#  'author': {'@type': 'Person',
#             'memberOf': {'@context': 'https://schema.org',
#                          '@type': 'NewsMediaOrganization',
#                          'logo': {'@type': 'ImageObject',
#                                   'height': 192,
#                                   'url': 'https://s2.abcstatics.com/comun/2018/img/iconos-metas/favicon-192x192.png',
#                                   'width': 192},
#                          'name': 'ABC de Sevilla',
#                          'url': 'https://sevilla.abc.es'},
#             'name': 'Soraya Fernández',
#             'url': 'https://sevilla.abc.es/autor/soraya-fernandez-6267/'},
#  'dateModified': '2023-09-01T04:23:30+02:00',
#  'datePublished': '2023-09-01T04:23:30+02:00',
#  'dateline': 'Spain',
#  'description': '«Ha sido coaccionado y hostigado por intentar faenar donde '
#                 'siempre», dicen los pescadores',
#  'headline': 'Gibraltar vuelve a impedir faenar a otro pesquero español',
#  'image': {'@type': 'ImageObject',
#            'height': '840',
#            'url': 'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg',
#            'width': '1200'},
#  'inLanguage': 'es',
#  'isAccessibleForFree': 'True',
#  'isPartOf': {'@type': ['CreativeWork', 'Product'],
#               'name': 'ABC de Sevilla',
#               'productID': 'sevilla.abc.es:premium'},
#  'keywords': ['Informaciones', 'Cádiz (Provincia)', 'ABC de Sevilla'],
#  'mainEntityOfPage': {'@id': 'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html',
#                       '@type': 'WebPage'},
#  'publisher': {'@id': 'https://sevilla.abc.es/#publisher',
#                '@type': 'Organization',
#                'logo': {'@type': 'ImageObject',
#                         'height': 60,
#                         'url': 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png',
#                         'width': 444},
#                'name': 'ABC Andalucía',
#                'sameAs': ['https://twitter.com/abcdesevilla/',
#                           'https://www.facebook.com/abcdesevilla/',
#                           'https://www.instagram.com/abcdesevilla/'],
#                'url': 'https://sevilla.abc.es'},
#  'speakable': {'@type': 'SpeakableSpecification',
#                'xpath': ['/html/head/title',
#                          "/html/head/meta[@name='description']/@content"]},
#  'wordCount': '483'}

# %%
only_keys3, keys_values3, trailed_keys3, only_pairs3, n_nestings3, steps3 = indir_recursive_json_destructure(article_json_test3)
print(n_nestings3, steps3, len(keys_values3), end="\n\n")
# Out:
# 4 120 28

# %%
only_pairs3
# Out:
# [('@context', 'https://schema.org'),
#  ('@type', 'NewsArticle'),
#  ('articleBody',
#   'Nuevo incidente con una embarcación pesquera española en las aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC el gerente de la Organización de Productores Pesqueros Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de otro pesquero con base en La Línea de la Concepción (Cádiz) que acudió a este caladero para capturar melva «y cuando llegó ya lo estaban esperando los de Medio Ambiente de Gibraltar. Es más de lo mismo. Ha sido coaccionado y hostigado por intentar faenar donde siempre ».Es el segundo hostigamiento de las autoridades del Peñón a pesqueros andaluces. El pasado 21 de agosto, la Policía gibraltareña retuvo a un pesquero español y acusó a su patrón de graves delitos supuestamente cometidos en aguas que España reclama como propias según establece el Tratado de Utrecht. El pesquero pudo seguir su curso tras la denuncia .ReincidenciaEl nuevo incidente, apenas nueve días después, ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer poco después de las nueve de la mañana. El patrón, un español de 33 años, ha sido denunciado por agentes de la Sección Marítima de la Policía Real de Gibraltar asistidos por el Departamento de Medio Ambiente y la Sección Marítima del Servicio de Aduanas de la colonia británica. Nicolás Fernández condena lo que está ocurriendo, y recuerda que lleva produciéndose años porque Gibraltar considera que dichas aguas son de soberanía británica, algo que no reconoce España.Aunque el dirigente de la patronal pesquera agradece la protesta formulada por el Ministerio de Asuntos Exteriores a Reino Unido por estos hechos, considera que este conflicto debería haber sido resuelto «hace muchos años. Estas llamadas de atención por parte del Gobierno son necesarias pero este problema no es nuevo. No vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar. O se sientan a establecer los límites de las aguas en las que pueden faenar los barcos nacionales o toman cartas en el asunto o tendrán que desplegar a las Fuerzas de Seguridad y al Ejército para que los pescadores puedan faenar», dijo.En ese sentido, Fernández anunció que hoy, viernes, mantendrá una reunión con el alcalde de La Línea de la Concepción, Juan Franco, un encuentro sobre el que no han querido adelantar acontecimientos ni el orden del día a tratar.Cabe recordar que desde este sector se exigió la semana pasada a los Gobiernos de España y del Peñón que se sentaran a establecer los límites de las aguas en las que pueden faenar los barcos nacionales, ante los repetidos incidentes que se están produciendo en esa zona. «Nosotros no vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar», manifestaba Fernández entonces, advirtiendo que «o se sientan y toman cartas en el asunto, o tendrán que poner fuerzas de seguridad y al Ejército para que los pescadores puedan pescar».'),
#  ('articleSection', 'andalucia'),
#  ('@type', 'Person'),
#  ('@context', 'https://schema.org'),
#  ('@type', 'NewsMediaOrganization'),
#  ('@type', 'ImageObject'),
#  ('height', 192),
#  ('url',
#   'https://s2.abcstatics.com/comun/2018/img/iconos-metas/favicon-192x192.png'),
#  ('width', 192),
#  ('@type', 'ImageObject'),
#  ('height', '840'),
#  ('url',
#   'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg'),
#  ('width', '1200'),
#  ('name', 'ABC de Sevilla'),
#  ('productID', 'sevilla.abc.es:premium'),
#  ('@id',
#   'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html'),
#  ('@type', 'WebPage'),
#  ('@id', 'https://sevilla.abc.es/#publisher'),
#  ('@type', 'Organization'),
#  ('@type', 'ImageObject'),
#  ('height', 60),
#  ('url', 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png'),
#  ('width', 444),
#  ('@type', 'SpeakableSpecification')]

# %%
keys_values3
# Out:
# [('@context', 'https://schema.org'),
#  ('@type', 'NewsArticle'),
#  ('articleBody',
#   'Nuevo incidente con una embarcación pesquera española en las aguas que rodean Gibraltar . Ocurrió ayer, según relató a ABC el gerente de la Organización de Productores Pesqueros Artesanales Conil/La Atunara, Nicolás Fernández . Se trata de otro pesquero con base en La Línea de la Concepción (Cádiz) que acudió a este caladero para capturar melva «y cuando llegó ya lo estaban esperando los de Medio Ambiente de Gibraltar. Es más de lo mismo. Ha sido coaccionado y hostigado por intentar faenar donde siempre ».Es el segundo hostigamiento de las autoridades del Peñón a pesqueros andaluces. El pasado 21 de agosto, la Policía gibraltareña retuvo a un pesquero español y acusó a su patrón de graves delitos supuestamente cometidos en aguas que España reclama como propias según establece el Tratado de Utrecht. El pesquero pudo seguir su curso tras la denuncia .ReincidenciaEl nuevo incidente, apenas nueve días después, ha sido confirmado por la Policía de Gibraltar . Ocurrió ayer poco después de las nueve de la mañana. El patrón, un español de 33 años, ha sido denunciado por agentes de la Sección Marítima de la Policía Real de Gibraltar asistidos por el Departamento de Medio Ambiente y la Sección Marítima del Servicio de Aduanas de la colonia británica. Nicolás Fernández condena lo que está ocurriendo, y recuerda que lleva produciéndose años porque Gibraltar considera que dichas aguas son de soberanía británica, algo que no reconoce España.Aunque el dirigente de la patronal pesquera agradece la protesta formulada por el Ministerio de Asuntos Exteriores a Reino Unido por estos hechos, considera que este conflicto debería haber sido resuelto «hace muchos años. Estas llamadas de atención por parte del Gobierno son necesarias pero este problema no es nuevo. No vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar. O se sientan a establecer los límites de las aguas en las que pueden faenar los barcos nacionales o toman cartas en el asunto o tendrán que desplegar a las Fuerzas de Seguridad y al Ejército para que los pescadores puedan faenar», dijo.En ese sentido, Fernández anunció que hoy, viernes, mantendrá una reunión con el alcalde de La Línea de la Concepción, Juan Franco, un encuentro sobre el que no han querido adelantar acontecimientos ni el orden del día a tratar.Cabe recordar que desde este sector se exigió la semana pasada a los Gobiernos de España y del Peñón que se sentaran a establecer los límites de las aguas en las que pueden faenar los barcos nacionales, ante los repetidos incidentes que se están produciendo en esa zona. «Nosotros no vamos a dejar de pelear, vamos a seguir poniendo de manifiesto que es un abuso de las autoridades de Gibraltar», manifestaba Fernández entonces, advirtiendo que «o se sientan y toman cartas en el asunto, o tendrán que poner fuerzas de seguridad y al Ejército para que los pescadores puedan pescar».'),
#  ('articleSection', 'andalucia'),
#  ('@type', 'Person'),
#  ('@context', 'https://schema.org'),
#  ('@type', 'NewsMediaOrganization'),
#  ('@type', 'ImageObject'),
#  ('height', 192),
#  ('url',
#   'https://s2.abcstatics.com/comun/2018/img/iconos-metas/favicon-192x192.png'),
#  ('width', 192),
#  ('@type', 'ImageObject'),
#  ('height', '840'),
#  ('url',
#   'https://s1.abcstatics.com/abc/sevilla/multimedia/andalucia/2023/08/31/pesquero-R5tPJ4D7aYBzgHpDl22q2eI-1200x840@abc.jpg'),
#  ('width', '1200'),
#  ('@type', ('CreativeWork', 'Product')),
#  ('name', 'ABC de Sevilla'),
#  ('productID', 'sevilla.abc.es:premium'),
#  ('@id',
#   'https://sevilla.abc.es/andalucia/cadiz/gibraltar-vuelve-impedir-faenar-pesquero-espanol-20230901234418-nts.html'),
#  ('@type', 'WebPage'),
#  ('@id', 'https://sevilla.abc.es/#publisher'),
#  ('@type', 'Organization'),
#  ('@type', 'ImageObject'),
#  ('height', 60),
#  ('url', 'https://static3-sevilla.abc.es/2015/img/logo-andalucia.png'),
#  ('width', 444),
#  ('@type', 'SpeakableSpecification'),
#  ('xpath',
#   ('/html/head/title', "/html/head/meta[@name='description']/@content"))]
